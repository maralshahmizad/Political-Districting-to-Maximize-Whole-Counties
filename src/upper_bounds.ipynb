# %%
from utils import read_graph_from_json, update_attributes, get_k_L_U
filepath = '..\\dat\\'
district_types = ['CD','SS','SH']

from number_of_districts import states as all_states
states = all_states.copy()
states.remove('HI')
print(states)
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
from main import get_max_whole_UBs
results = dict()

for state in states:

    # read graph
    filename = state + '_county.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)
    
    for district_type in district_types:

        (k, L, U) = get_k_L_U(G, state, district_type)
        if k <= 1:
            print(f"Skipping {state} {district_type} because k = {k}.")
            continue

        results[state, district_type] = get_max_whole_UBs(G, L, U, k, verbose=False)
# Out:
# Starting AK with k = 1 and deviation = 0.01
# Thus, we have L = 729725 and U = 737057
# Skipping AK CD because k = 1.
# Starting AK with k = 20 and deviation = 0.1
# Thus, we have L = 34837 and U = 38503
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-04-01
# Adding non-dominated, minimal constraints:
# ['02020']
# ['02090']
# ['02122']
# ['02170']
# Time to generate initial inequalities: 0.9 seconds.
# Adding non-dominated, minimal constraints:
# ['02020']
# ['02090']
# ['02122']
# ['02170']
# Time to generate initial inequalities: 1.28 seconds.
# Adding non-dominated, minimal constraints:
# ['02020']
# ['02090']
# ['02122']
# ['02170']
# Time to generate initial inequalities: 1.24 seconds.
# Adding non-dominated, minimal constraints:
# ['02020']
# ['02090']
# ['02122']
# ['02170']
# Time to generate initial inequalities: 1.27 seconds.
# Starting AK with k = 40 and deviation = 0.1
# Thus, we have L = 17419 and U = 19251
# Adding non-dominated, minimal constraints:
# ['02122']
# ['02170']
# ['02198', '02195', '02130', '02275']
# ['02090']
# ['02110']
# ['02020']
# Time to generate initial inequalities: 0.57 seconds.
# Adding non-dominated, minimal constraints:
# ['02122']
# ['02170']
# ['02198', '02195', '02130', '02275']
# ['02090']
# ['02110']
# ['02020']
# Time to generate initial inequalities: 0.57 seconds.
# Adding non-dominated, minimal constraints:
# ['02122']
# ['02170']
# ['02198', '02195', '02130', '02275']
# ['02090']
# ['02110']
# ['02020']
# Time to generate initial inequalities: 0.56 seconds.
# Adding non-dominated, minimal constraints:
# ['02122']
# ['02170']
# ['02198', '02195', '02130', '02275']
# ['02090']
# ['02110']
# ['02020']
# Time to generate initial inequalities: 0.59 seconds.
# Starting AL with k = 7 and deviation = 0.01
# Thus, we have L = 714166 and U = 721342
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.71 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.23 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.6 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.42 seconds.
# Starting AL with k = 35 and deviation = 0.1
# Thus, we have L = 136374 and U = 150728
# Adding non-dominated, minimal constraints:
# ['01081']
# ['01073']
# ['01097']
# ['01003']
# ['01117']
# ['01089']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 1.89 seconds.
# Dropped 4 and reduced from {'01111', '01029', '01027', '01037', '01121', '01123', '01049', '01015', '01009', '01019', '01095', '01115', '01055'} to ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055'].
# Adding non-dominated, minimal constraints:
# ['01081']
# ['01073']
# ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055']
# ['01097']
# ['01003']
# ['01117']
# ['01089']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 3.4 seconds.
# Dropped 4 and reduced from {'01111', '01029', '01027', '01037', '01121', '01123', '01049', '01015', '01009', '01019', '01095', '01115', '01055'} to ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055'].
# Adding non-dominated, minimal constraints:
# ['01081']
# ['01073']
# ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055']
# ['01097']
# ['01003']
# ['01117']
# ['01089']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 3.39 seconds.
# Dropped 4 and reduced from {'01111', '01029', '01027', '01037', '01121', '01123', '01049', '01015', '01009', '01019', '01095', '01115', '01055'} to ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055'].
# Adding non-dominated, minimal constraints:
# ['01081']
# ['01073']
# ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055']
# ['01097']
# ['01003']
# ['01117']
# ['01089']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 3.79 seconds.
# Starting AL with k = 105 and deviation = 0.1
# Thus, we have L = 45458 and U = 50242
# Adding non-dominated, minimal constraints:
# ['01121']
# ['01127']
# ['01115']
# ['01055']
# ['01009']
# ['01089']
# ['01049']
# ['01033']
# ['01073']
# ['01031']
# ['01069']
# ['01097']
# ['01083']
# ['01117']
# ['01077']
# ['01081']
# ['01071']
# ['01095']
# ['01003']
# ['01015']
# ['01103']
# ['01113']
# ['01001']
# ['01051']
# ['01043']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 0.86 seconds.
# Adding non-dominated, minimal constraints:
# ['01121']
# ['01127']
# ['01115']
# ['01055']
# ['01009']
# ['01089']
# ['01049']
# ['01033']
# ['01073']
# ['01031']
# ['01069']
# ['01097']
# ['01083']
# ['01117']
# ['01077']
# ['01081']
# ['01071']
# ['01095']
# ['01003']
# ['01015']
# ['01103']
# ['01113']
# ['01001']
# ['01051']
# ['01043']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 1.03 seconds.
# Adding non-dominated, minimal constraints:
# ['01121']
# ['01127']
# ['01115']
# ['01055']
# ['01009']
# ['01089']
# ['01049']
# ['01033']
# ['01073']
# ['01031']
# ['01069']
# ['01097']
# ['01083']
# ['01117']
# ['01077']
# ['01081']
# ['01071']
# ['01095']
# ['01003']
# ['01015']
# ['01103']
# ['01113']
# ['01001']
# ['01051']
# ['01043']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 0.98 seconds.
# Adding non-dominated, minimal constraints:
# ['01121']
# ['01127']
# ['01115']
# ['01055']
# ['01009']
# ['01089']
# ['01049']
# ['01033']
# ['01073']
# ['01031']
# ['01069']
# ['01097']
# ['01083']
# ['01117']
# ['01077']
# ['01081']
# ['01071']
# ['01095']
# ['01003']
# ['01015']
# ['01103']
# ['01113']
# ['01001']
# ['01051']
# ['01043']
# ['01101']
# ['01125']
# Time to generate initial inequalities: 1.4 seconds.
# Starting AR with k = 4 and deviation = 0.01
# Thus, we have L = 749117 and U = 756645
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.82 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.86 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.22 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.78 seconds.
# Starting AR with k = 35 and deviation = 0.1
# Thus, we have L = 81742 and U = 90345
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05045']
# ['05131']
# ['05143']
# ['05119']
# ['05051']
# ['05007']
# ['05031']
# Time to generate initial inequalities: 2.3 seconds.
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05045']
# ['05131']
# ['05143']
# ['05119']
# ['05051']
# ['05007']
# ['05031']
# Time to generate initial inequalities: 2.17 seconds.
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05045']
# ['05131']
# ['05143']
# ['05119']
# ['05051']
# ['05007']
# ['05031']
# Time to generate initial inequalities: 2.56 seconds.
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05045']
# ['05131']
# ['05143']
# ['05119']
# ['05051']
# ['05007']
# ['05031']
# Time to generate initial inequalities: 2.31 seconds.
# Starting AR with k = 100 and deviation = 0.1
# Thus, we have L = 28610 and U = 31621
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05063']
# ['05045']
# ['05031']
# ['05055']
# ['05059']
# ['05007']
# ['05085']
# ['05009']
# ['05035']
# ['05033']
# ['05143']
# ['05069']
# ['05051']
# ['05093']
# ['05091']
# ['05119']
# ['05005']
# ['05115']
# ['05131']
# ['05145']
# ['05139']
# Time to generate initial inequalities: 1.19 seconds.
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05063']
# ['05045']
# ['05031']
# ['05055']
# ['05059']
# ['05007']
# ['05085']
# ['05009']
# ['05035']
# ['05033']
# ['05143']
# ['05069']
# ['05051']
# ['05093']
# ['05091']
# ['05119']
# ['05005']
# ['05115']
# ['05131']
# ['05145']
# ['05139']
# Time to generate initial inequalities: 1.39 seconds.
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05063']
# ['05045']
# ['05031']
# ['05055']
# ['05059']
# ['05007']
# ['05085']
# ['05009']
# ['05035']
# ['05033']
# ['05143']
# ['05069']
# ['05051']
# ['05093']
# ['05091']
# ['05119']
# ['05005']
# ['05115']
# ['05131']
# ['05145']
# ['05139']
# Time to generate initial inequalities: 1.35 seconds.
# Adding non-dominated, minimal constraints:
# ['05125']
# ['05063']
# ['05045']
# ['05031']
# ['05055']
# ['05059']
# ['05007']
# ['05085']
# ['05009']
# ['05035']
# ['05033']
# ['05143']
# ['05069']
# ['05051']
# ['05093']
# ['05091']
# ['05119']
# ['05005']
# ['05115']
# ['05131']
# ['05145']
# ['05139']
# Time to generate initial inequalities: 3.62 seconds.
# Starting AZ with k = 9 and deviation = 0.01
# Thus, we have L = 790639 and U = 798584
# Adding non-dominated, minimal constraints:
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.48 seconds.
# Adding non-dominated, minimal constraints:
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.46 seconds.
# Adding non-dominated, minimal constraints:
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.46 seconds.
# Adding non-dominated, minimal constraints:
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.45 seconds.
# Starting AZ with k = 30 and deviation = 0.1
# Thus, we have L = 226465 and U = 250302
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.07 seconds.
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.08 seconds.
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.07 seconds.
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.08 seconds.
# Starting AZ with k = 30 and deviation = 0.1
# Thus, we have L = 226465 and U = 250302
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.07 seconds.
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.08 seconds.
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.07 seconds.
# Adding non-dominated, minimal constraints:
# ['04021']
# ['04019']
# ['04013']
# Time to generate initial inequalities: 0.08 seconds.
# Starting CA with k = 52 and deviation = 0.01
# Thus, we have L = 756549 and U = 764152
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 1.55 seconds.
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 1.5 seconds.
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 1.62 seconds.
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 1.52 seconds.
# Starting CA with k = 40 and deviation = 0.1
# Thus, we have L = 939033 and U = 1037878
# Dropped 1 and reduced from {'06029', '06019', '06107', '06053', '06111', '06079', '06031', '06083'} to ['06029', '06019', '06107', '06053', '06111', '06079', '06083'].
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06029', '06019', '06107', '06053', '06111', '06079', '06083']
# ['06067']
# ['06065']
# ['06059']
# Time to generate initial inequalities: 1.87 seconds.
# Dropped 1 and reduced from {'06029', '06019', '06107', '06053', '06111', '06079', '06031', '06083'} to ['06029', '06019', '06107', '06053', '06111', '06079', '06083'].
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06029', '06019', '06107', '06053', '06111', '06079', '06083']
# ['06067']
# ['06065']
# ['06059']
# Time to generate initial inequalities: 1.97 seconds.
# Dropped 1 and reduced from {'06029', '06019', '06107', '06053', '06111', '06079', '06031', '06083'} to ['06029', '06019', '06107', '06053', '06111', '06079', '06083'].
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06029', '06019', '06107', '06053', '06111', '06079', '06083']
# ['06067']
# ['06065']
# ['06059']
# Time to generate initial inequalities: 1.93 seconds.
# Dropped 1 and reduced from {'06029', '06019', '06107', '06053', '06111', '06079', '06031', '06083'} to ['06029', '06019', '06107', '06053', '06111', '06079', '06083'].
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06029', '06019', '06107', '06053', '06111', '06079', '06083']
# ['06067']
# ['06065']
# ['06059']
# Time to generate initial inequalities: 2.03 seconds.
# Starting CA with k = 80 and deviation = 0.1
# Thus, we have L = 469517 and U = 518939
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06099']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 0.64 seconds.
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06099']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 0.84 seconds.
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06099']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 0.78 seconds.
# Adding non-dominated, minimal constraints:
# ['06071']
# ['06081']
# ['06085']
# ['06073']
# ['06013']
# ['06001']
# ['06037']
# ['06075']
# ['06099']
# ['06029']
# ['06111']
# ['06067']
# ['06077']
# ['06065']
# ['06059']
# ['06019']
# Time to generate initial inequalities: 0.98 seconds.
# Starting CO with k = 8 and deviation = 0.01
# Thus, we have L = 718106 and U = 725322
# Dropped 1 and reduced from {'08059', '08001', '08031', '08005'} to ['08059', '08001', '08005'].
# Adding non-dominated, minimal constraints:
# ['08041']
# ['08059', '08001', '08005']
# Time to generate initial inequalities: 1.55 seconds.
# Dropped 1 and reduced from {'08059', '08001', '08031', '08005'} to ['08059', '08001', '08005'].
# Adding non-dominated, minimal constraints:
# ['08041']
# ['08059', '08001', '08005']
# Time to generate initial inequalities: 1.79 seconds.
# Dropped 1 and reduced from {'08059', '08001', '08031', '08005'} to ['08059', '08001', '08005'].
# Adding non-dominated, minimal constraints:
# ['08041']
# ['08059', '08001', '08005']
# Time to generate initial inequalities: 1.64 seconds.
# Adding non-dominated, minimal constraints:
# ['08041']
# ['08059', '08001', '08005']
# Time to generate initial inequalities: 1.61 seconds.
# Starting CO with k = 35 and deviation = 0.1
# Thus, we have L = 156716 and U = 173211
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08001']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 1.39 seconds.
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08001']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 1.43 seconds.
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08001']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 1.5 seconds.
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08001']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 1.56 seconds.
# Starting CO with k = 65 and deviation = 0.1
# Thus, we have L = 84386 and U = 93267
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08077']
# ['08001']
# ['08101']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 1.78 seconds.
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08077']
# ['08001']
# ['08101']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 1.79 seconds.
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08077']
# ['08001']
# ['08101']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 1.83 seconds.
# Adding non-dominated, minimal constraints:
# ['08059']
# ['08013']
# ['08005']
# ['08031']
# ['08123']
# ['08077']
# ['08001']
# ['08101']
# ['08069']
# ['08035']
# ['08041']
# Time to generate initial inequalities: 2.02 seconds.
# Starting CT with k = 5 and deviation = 0.01
# Thus, we have L = 717583 and U = 724794
# Adding non-dominated, minimal constraints:
# ['09009']
# ['09003']
# ['09001']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09009']
# ['09003']
# ['09001']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09009']
# ['09003']
# ['09001']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09009']
# ['09003']
# ['09001']
# Time to generate initial inequalities: 0.01 seconds.
# Starting CT with k = 36 and deviation = 0.1
# Thus, we have L = 95157 and U = 105173
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Starting CT with k = 151 and deviation = 0.1
# Thus, we have L = 22687 and U = 25074
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['09007']
# ['09003']
# ['09001']
# ['09009']
# ['09015']
# ['09013']
# ['09005']
# ['09011']
# Time to generate initial inequalities: 0.01 seconds.
# Starting DE with k = 1 and deviation = 0.01
# Thus, we have L = 984999 and U = 994897
# Skipping DE CD because k = 1.
# Starting DE with k = 21 and deviation = 0.1
# Thus, we have L = 44784 and U = 49497
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Starting DE with k = 41 and deviation = 0.1
# Thus, we have L = 22938 and U = 25352
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Adding non-dominated, minimal constraints:
# ['10005']
# ['10003']
# ['10001']
# Time to generate initial inequalities: 0.0 seconds.
# Starting FL with k = 28 and deviation = 0.01
# Thus, we have L = 765375 and U = 773067
# Dropped 3 and reduced from {'12091', '12033', '12113', '12131'} to ['12131'].
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12131']
# ['12095']
# ['12099']
# ['12011']
# ['12015', '12071', '12021', '12051']
# ['12103']
# Time to generate initial inequalities: 9.4 seconds.
# Dropped 3 and reduced from {'12091', '12033', '12113', '12131'} to ['12131'].
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12131']
# ['12095']
# ['12099']
# ['12011']
# ['12015', '12071', '12021', '12051']
# ['12103']
# Time to generate initial inequalities: 9.69 seconds.
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12131']
# ['12095']
# ['12099']
# ['12011']
# ['12015', '12071', '12021', '12051']
# ['12103']
# Time to generate initial inequalities: 9.63 seconds.
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12131']
# ['12095']
# ['12099']
# ['12011']
# ['12015', '12071', '12021', '12051']
# ['12103']
# Time to generate initial inequalities: 10.22 seconds.
# Starting FL with k = 40 and deviation = 0.1
# Thus, we have L = 511532 and U = 565377
# Dropped 2 and reduced from {'12091', '12033', '12113'} to ['12091'].
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12091']
# ['12009']
# ['12095']
# ['12071']
# ['12099']
# ['12011']
# ['12105']
# ['12103']
# Time to generate initial inequalities: 3.66 seconds.
# Dropped 2 and reduced from {'12091', '12033', '12113'} to ['12091'].
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12091']
# ['12009']
# ['12095']
# ['12071']
# ['12099']
# ['12011']
# ['12105']
# ['12103']
# Time to generate initial inequalities: 3.65 seconds.
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12009']
# ['12095']
# ['12071']
# ['12099']
# ['12011']
# ['12091']
# ['12105']
# ['12103']
# Time to generate initial inequalities: 3.54 seconds.
# Adding non-dominated, minimal constraints:
# ['12031']
# ['12086']
# ['12057']
# ['12009']
# ['12095']
# ['12071']
# ['12099']
# ['12011']
# ['12091']
# ['12105']
# ['12103']
# Time to generate initial inequalities: 3.51 seconds.
# Starting FL with k = 120 and deviation = 0.1
# Thus, we have L = 170511 and U = 188459
# Adding non-dominated, minimal constraints:
# ['12073']
# ['12081']
# ['12057']
# ['12053']
# ['12117']
# ['12091']
# ['12033']
# ['12083']
# ['12101']
# ['12097']
# ['12086']
# ['12099']
# ['12105']
# ['12103']
# ['12109']
# ['12069']
# ['12071']
# ['12111']
# ['12019']
# ['12031']
# ['12115']
# ['12021']
# ['12009']
# ['12095']
# ['12011']
# ['12001']
# ['12127']
# Time to generate initial inequalities: 1.78 seconds.
# Adding non-dominated, minimal constraints:
# ['12073']
# ['12081']
# ['12057']
# ['12053']
# ['12117']
# ['12091']
# ['12033']
# ['12083']
# ['12101']
# ['12097']
# ['12086']
# ['12099']
# ['12105']
# ['12103']
# ['12109']
# ['12069']
# ['12071']
# ['12111']
# ['12019']
# ['12031']
# ['12115']
# ['12021']
# ['12009']
# ['12095']
# ['12011']
# ['12001']
# ['12127']
# Time to generate initial inequalities: 1.74 seconds.
# Adding non-dominated, minimal constraints:
# ['12073']
# ['12081']
# ['12057']
# ['12053']
# ['12117']
# ['12091']
# ['12033']
# ['12083']
# ['12101']
# ['12097']
# ['12086']
# ['12099']
# ['12105']
# ['12113']
# ['12103']
# ['12109']
# ['12069']
# ['12071']
# ['12111']
# ['12019']
# ['12031']
# ['12115']
# ['12021']
# ['12009']
# ['12095']
# ['12011']
# ['12001']
# ['12127']
# Time to generate initial inequalities: 1.73 seconds.
# Adding non-dominated, minimal constraints:
# ['12073']
# ['12081']
# ['12057']
# ['12053']
# ['12117']
# ['12091']
# ['12033']
# ['12083']
# ['12101']
# ['12097']
# ['12086']
# ['12099']
# ['12105']
# ['12113']
# ['12103']
# ['12109']
# ['12069']
# ['12071']
# ['12111']
# ['12019']
# ['12031']
# ['12115']
# ['12021']
# ['12009']
# ['12095']
# ['12011']
# ['12001']
# ['12127']
# Time to generate initial inequalities: 1.95 seconds.
# Starting GA with k = 14 and deviation = 0.01
# Thus, we have L = 761311 and U = 768961
# Adding non-dominated, minimal constraints:
# ['13135']
# ['13121']
# Time to generate initial inequalities: 3.69 seconds.
# Adding non-dominated, minimal constraints:
# ['13135']
# ['13121']
# Time to generate initial inequalities: 3.42 seconds.
# Adding non-dominated, minimal constraints:
# ['13135']
# ['13121']
# Time to generate initial inequalities: 3.5 seconds.
# Adding non-dominated, minimal constraints:
# ['13135']
# ['13121']
# Time to generate initial inequalities: 4.17 seconds.
# Starting GA with k = 56 and deviation = 0.1
# Thus, we have L = 181720 and U = 200848
# Dropped 5 and reduced from {'13123', '13047', '13213', '13115', '13295', '13055', '13227', '13015', '13083', '13129', '13313'} to ['13047', '13213', '13115', '13295', '13129', '13313'].
# Adding non-dominated, minimal constraints:
# ['13139']
# ['13117']
# ['13057']
# ['13245']
# ['13047', '13213', '13115', '13295', '13129', '13313']
# ['13135']
# ['13151']
# ['13215']
# ['13063']
# ['13051']
# ['13067']
# ['13121']
# ['13089']
# Time to generate initial inequalities: 11.58 seconds.
# Dropped 5 and reduced from {'13123', '13047', '13213', '13115', '13295', '13055', '13227', '13015', '13083', '13129', '13313'} to ['13047', '13213', '13115', '13295', '13129', '13313'].
# Adding non-dominated, minimal constraints:
# ['13139']
# ['13117']
# ['13057']
# ['13245']
# ['13047', '13213', '13115', '13295', '13129', '13313']
# ['13135']
# ['13151']
# ['13215']
# ['13063']
# ['13051']
# ['13067']
# ['13121']
# ['13089']
# Time to generate initial inequalities: 11.18 seconds.
# Dropped 5 and reduced from {'13123', '13047', '13213', '13115', '13295', '13055', '13227', '13015', '13083', '13129', '13313'} to ['13047', '13213', '13115', '13295', '13129', '13313'].
# Adding non-dominated, minimal constraints:
# ['13139']
# ['13117']
# ['13057']
# ['13245']
# ['13047', '13213', '13115', '13295', '13129', '13313']
# ['13135']
# ['13151']
# ['13215']
# ['13063']
# ['13051']
# ['13067']
# ['13121']
# ['13089']
# Time to generate initial inequalities: 11.66 seconds.
# Dropped 5 and reduced from {'13123', '13047', '13213', '13115', '13295', '13055', '13227', '13015', '13083', '13129', '13313'} to ['13047', '13213', '13115', '13295', '13129', '13313'].
# Adding non-dominated, minimal constraints:
# ['13139']
# ['13117']
# ['13057']
# ['13245']
# ['13047', '13213', '13115', '13295', '13129', '13313']
# ['13135']
# ['13151']
# ['13215']
# ['13063']
# ['13051']
# ['13067']
# ['13121']
# ['13089']
# Time to generate initial inequalities: 12.53 seconds.
# Starting GA with k = 180 and deviation = 0.1
# Thus, we have L = 56536 and U = 62486
# Adding non-dominated, minimal constraints:
# ['13045']
# ['13113']
# ['13285']
# ['13127']
# ['13073']
# ['13151']
# ['13121']
# ['13179']
# ['13247']
# ['13157']
# ['13077']
# ['13185']
# ['13153']
# ['13047']
# ['13117']
# ['13223']
# ['13245']
# ['13021']
# ['13015']
# ['13295']
# ['13063']
# ['13067']
# ['13115']
# ['13313']
# ['13297']
# ['13031']
# ['13057']
# ['13059']
# ['13103']
# ['13135']
# ['13255']
# ['13217']
# ['13051']
# ['13097']
# ['13139']
# ['13215']
# ['13095']
# ['13013']
# ['13089']
# Time to generate initial inequalities: 10.08 seconds.
# Adding non-dominated, minimal constraints:
# ['13045']
# ['13113']
# ['13285']
# ['13127']
# ['13073']
# ['13151']
# ['13121']
# ['13179']
# ['13247']
# ['13157']
# ['13077']
# ['13185']
# ['13153']
# ['13047']
# ['13117']
# ['13223']
# ['13245']
# ['13021']
# ['13015']
# ['13295']
# ['13063']
# ['13067']
# ['13115']
# ['13313']
# ['13297']
# ['13031']
# ['13057']
# ['13059']
# ['13103']
# ['13135']
# ['13255']
# ['13217']
# ['13051']
# ['13097']
# ['13139']
# ['13215']
# ['13095']
# ['13013']
# ['13089']
# Time to generate initial inequalities: 10.02 seconds.
# Adding non-dominated, minimal constraints:
# ['13045']
# ['13113']
# ['13285']
# ['13127']
# ['13073']
# ['13151']
# ['13121']
# ['13179']
# ['13247']
# ['13157']
# ['13077']
# ['13185']
# ['13153']
# ['13047']
# ['13117']
# ['13223']
# ['13245']
# ['13021']
# ['13015']
# ['13295']
# ['13063']
# ['13067']
# ['13115']
# ['13313']
# ['13297']
# ['13031']
# ['13057']
# ['13059']
# ['13103']
# ['13135']
# ['13255']
# ['13217']
# ['13051']
# ['13097']
# ['13139']
# ['13215']
# ['13095']
# ['13013']
# ['13089']
# Time to generate initial inequalities: 10.33 seconds.
# Adding non-dominated, minimal constraints:
# ['13045']
# ['13113']
# ['13285']
# ['13127']
# ['13073']
# ['13151']
# ['13121']
# ['13179']
# ['13247']
# ['13157']
# ['13077']
# ['13185']
# ['13153']
# ['13047']
# ['13117']
# ['13223']
# ['13245']
# ['13021']
# ['13015']
# ['13295']
# ['13063']
# ['13067']
# ['13115']
# ['13313']
# ['13297']
# ['13031']
# ['13057']
# ['13059']
# ['13103']
# ['13135']
# ['13255']
# ['13217']
# ['13051']
# ['13097']
# ['13139']
# ['13215']
# ['13095']
# ['13013']
# ['13089']
# Time to generate initial inequalities: 14.42 seconds.
# Starting IA with k = 4 and deviation = 0.01
# Thus, we have L = 793605 and U = 801580
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.36 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.8 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.79 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.99 seconds.
# Starting IA with k = 50 and deviation = 0.1
# Thus, we have L = 60618 and U = 66997
# Adding non-dominated, minimal constraints:
# ['19153']
# ['19163']
# ['19013']
# ['19193']
# ['19113']
# ['19049']
# ['19103']
# ['19061']
# ['19155']
# ['19169']
# Time to generate initial inequalities: 4.59 seconds.
# Adding non-dominated, minimal constraints:
# ['19153']
# ['19163']
# ['19013']
# ['19193']
# ['19113']
# ['19049']
# ['19103']
# ['19061']
# ['19155']
# ['19169']
# Time to generate initial inequalities: 4.46 seconds.
# Adding non-dominated, minimal constraints:
# ['19153']
# ['19163']
# ['19013']
# ['19193']
# ['19113']
# ['19049']
# ['19103']
# ['19061']
# ['19155']
# ['19169']
# Time to generate initial inequalities: 4.72 seconds.
# Adding non-dominated, minimal constraints:
# ['19153']
# ['19163']
# ['19013']
# ['19193']
# ['19113']
# ['19049']
# ['19103']
# ['19061']
# ['19155']
# ['19169']
# Time to generate initial inequalities: 4.67 seconds.
# Starting IA with k = 100 and deviation = 0.1
# Thus, we have L = 30309 and U = 33498
# Adding non-dominated, minimal constraints:
# ['19179']
# ['19057']
# ['19061']
# ['19187']
# ['19163']
# ['19013']
# ['19193']
# ['19127']
# ['19045']
# ['19049']
# ['19169']
# ['19167']
# ['19153']
# ['19033']
# ['19103']
# ['19181']
# ['19139']
# ['19111']
# ['19099']
# ['19113']
# ['19155']
# Time to generate initial inequalities: 3.31 seconds.
# Dropped 2 and reduced from {'19131', '19019', '19067', '19043', '19089', '19191', '19005', '19065', '19017', '19037'} to ['19131', '19019', '19043', '19191', '19005', '19065', '19017', '19037'].
# Adding non-dominated, minimal constraints:
# ['19179']
# ['19057']
# ['19061']
# ['19187']
# ['19163']
# ['19013']
# ['19193']
# ['19127']
# ['19045']
# ['19049']
# ['19131', '19019', '19043', '19191', '19005', '19065', '19017', '19037']
# ['19169']
# ['19167']
# ['19153']
# ['19033']
# ['19103']
# ['19181']
# ['19139']
# ['19111']
# ['19099']
# ['19113']
# ['19155']
# Time to generate initial inequalities: 5.72 seconds.
# Dropped 2 and reduced from {'19131', '19019', '19067', '19043', '19089', '19191', '19005', '19065', '19017', '19037'} to ['19131', '19019', '19043', '19191', '19005', '19065', '19017', '19037'].
# Adding non-dominated, minimal constraints:
# ['19179']
# ['19057']
# ['19061']
# ['19187']
# ['19163']
# ['19013']
# ['19193']
# ['19127']
# ['19045']
# ['19049']
# ['19131', '19019', '19043', '19191', '19005', '19065', '19017', '19037']
# ['19169']
# ['19167']
# ['19153']
# ['19033']
# ['19103']
# ['19181']
# ['19139']
# ['19111']
# ['19099']
# ['19113']
# ['19155']
# Time to generate initial inequalities: 5.9 seconds.
# Dropped 2 and reduced from {'19131', '19019', '19067', '19043', '19089', '19191', '19005', '19065', '19017', '19037'} to ['19131', '19019', '19043', '19191', '19005', '19065', '19017', '19037'].
# Adding non-dominated, minimal constraints:
# ['19179']
# ['19057']
# ['19061']
# ['19187']
# ['19163']
# ['19013']
# ['19193']
# ['19127']
# ['19045']
# ['19049']
# ['19131', '19019', '19043', '19191', '19005', '19065', '19017', '19037']
# ['19169']
# ['19167']
# ['19153']
# ['19033']
# ['19103']
# ['19181']
# ['19139']
# ['19111']
# ['19099']
# ['19113']
# ['19155']
# Time to generate initial inequalities: 8.64 seconds.
# Starting ID with k = 2 and deviation = 0.01
# Thus, we have L = 914956 and U = 924150
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.93 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.91 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.95 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.2 seconds.
# Starting ID with k = 35 and deviation = 0.1
# Thus, we have L = 49919 and U = 55173
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Dropped 1 and reduced from {'16017', '16021'} to ['16017'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# ['16017']
# Time to generate initial inequalities: 1.65 seconds.
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Dropped 1 and reduced from {'16017', '16021'} to ['16017'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# ['16017']
# Time to generate initial inequalities: 1.66 seconds.
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16017']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# Time to generate initial inequalities: 1.68 seconds.
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16017']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# Time to generate initial inequalities: 1.73 seconds.
# Starting ID with k = 35 and deviation = 0.1
# Thus, we have L = 49919 and U = 55173
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Dropped 1 and reduced from {'16017', '16021'} to ['16017'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# ['16017']
# Time to generate initial inequalities: 1.9 seconds.
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Dropped 1 and reduced from {'16017', '16021'} to ['16017'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# ['16017']
# Time to generate initial inequalities: 1.69 seconds.
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16017']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# Time to generate initial inequalities: 1.68 seconds.
# Dropped 2 and reduced from {'16035', '16079', '16057', '16061', '16069', '16049'} to ['16035', '16057', '16069', '16049'].
# Adding non-dominated, minimal constraints:
# ['16001']
# ['16017']
# ['16019']
# ['16083']
# ['16035', '16057', '16069', '16049']
# ['16027']
# ['16005']
# ['16055']
# Time to generate initial inequalities: 1.77 seconds.
# Starting IL with k = 17 and deviation = 0.01
# Thus, we have L = 749909 and U = 757445
# Adding non-dominated, minimal constraints:
# ['17043']
# ['17031']
# Time to generate initial inequalities: 3.72 seconds.
# Adding non-dominated, minimal constraints:
# ['17043']
# ['17031']
# Time to generate initial inequalities: 3.36 seconds.
# Adding non-dominated, minimal constraints:
# ['17043']
# ['17031']
# Time to generate initial inequalities: 3.32 seconds.
# Adding non-dominated, minimal constraints:
# ['17043']
# ['17031']
# Time to generate initial inequalities: 3.36 seconds.
# Starting IL with k = 59 and deviation = 0.1
# Thus, we have L = 206304 and U = 228019
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17043']
# ['17097']
# ['17089']
# ['17119']
# ['17111']
# ['17031']
# ['17197']
# ['17201']
# Time to generate initial inequalities: 3.69 seconds.
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17043']
# ['17097']
# ['17089']
# ['17119']
# ['17111']
# ['17031']
# ['17197']
# ['17201']
# Time to generate initial inequalities: 3.89 seconds.
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17043']
# ['17097']
# ['17089']
# ['17119']
# ['17111']
# ['17031']
# ['17197']
# ['17201']
# Time to generate initial inequalities: 3.31 seconds.
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17043']
# ['17097']
# ['17089']
# ['17119']
# ['17111']
# ['17031']
# ['17197']
# ['17201']
# Time to generate initial inequalities: 4.22 seconds.
# Starting IL with k = 118 and deviation = 0.1
# Thus, we have L = 103152 and U = 114009
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17167']
# ['17043']
# ['17097']
# ['17119']
# ['17089']
# ['17111']
# ['17161']
# ['17031']
# ['17143']
# ['17019']
# ['17093']
# ['17197']
# ['17113']
# ['17201']
# ['17179']
# Time to generate initial inequalities: 3.83 seconds.
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17167']
# ['17043']
# ['17097']
# ['17119']
# ['17089']
# ['17111']
# ['17161']
# ['17031']
# ['17143']
# ['17019']
# ['17093']
# ['17197']
# ['17113']
# ['17201']
# ['17179']
# Time to generate initial inequalities: 4.39 seconds.
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17167']
# ['17043']
# ['17097']
# ['17119']
# ['17089']
# ['17111']
# ['17161']
# ['17031']
# ['17143']
# ['17019']
# ['17093']
# ['17197']
# ['17113']
# ['17201']
# ['17179']
# Time to generate initial inequalities: 3.88 seconds.
# Adding non-dominated, minimal constraints:
# ['17163']
# ['17167']
# ['17043']
# ['17097']
# ['17119']
# ['17089']
# ['17111']
# ['17161']
# ['17031']
# ['17143']
# ['17019']
# ['17093']
# ['17197']
# ['17113']
# ['17201']
# ['17179']
# Time to generate initial inequalities: 4.77 seconds.
# Starting IN with k = 9 and deviation = 0.01
# Thus, we have L = 750178 and U = 757717
# Adding non-dominated, minimal constraints:
# ['18097']
# Time to generate initial inequalities: 1.84 seconds.
# Adding non-dominated, minimal constraints:
# ['18097']
# Time to generate initial inequalities: 1.75 seconds.
# Adding non-dominated, minimal constraints:
# ['18097']
# Time to generate initial inequalities: 1.88 seconds.
# Adding non-dominated, minimal constraints:
# ['18097']
# Time to generate initial inequalities: 2.34 seconds.
# Starting IN with k = 50 and deviation = 0.1
# Thus, we have L = 128926 and U = 142496
# Adding non-dominated, minimal constraints:
# ['18063']
# ['18157']
# ['18057']
# ['18081']
# ['18143', '18043', '18077', '18019', '18175']
# ['18163']
# ['18003']
# ['18039']
# ['18089']
# ['18127']
# ['18141']
# ['18097']
# Time to generate initial inequalities: 4.3 seconds.
# Adding non-dominated, minimal constraints:
# ['18063']
# ['18157']
# ['18057']
# ['18081']
# ['18143', '18043', '18077', '18019', '18175']
# ['18163']
# ['18003']
# ['18039']
# ['18089']
# ['18127']
# ['18141']
# ['18097']
# Time to generate initial inequalities: 4.62 seconds.
# Adding non-dominated, minimal constraints:
# ['18063']
# ['18157']
# ['18057']
# ['18081']
# ['18143', '18043', '18077', '18019', '18175']
# ['18163']
# ['18003']
# ['18039']
# ['18089']
# ['18127']
# ['18141']
# ['18097']
# Time to generate initial inequalities: 4.31 seconds.
# Adding non-dominated, minimal constraints:
# ['18063']
# ['18157']
# ['18057']
# ['18081']
# ['18143', '18043', '18077', '18019', '18175']
# ['18163']
# ['18003']
# ['18039']
# ['18089']
# ['18127']
# ['18141']
# ['18097']
# Time to generate initial inequalities: 5.61 seconds.
# Starting IN with k = 100 and deviation = 0.1
# Thus, we have L = 64463 and U = 71248
# Adding non-dominated, minimal constraints:
# ['18019']
# ['18043']
# ['18081']
# ['18005']
# ['18085']
# ['18095']
# ['18063']
# ['18087', '18151', '18033']
# ['18167']
# ['18057']
# ['18089']
# ['18059']
# ['18157']
# ['18035']
# ['18163']
# ['18003']
# ['18141']
# ['18097']
# ['18091']
# ['18109']
# ['18039']
# ['18067']
# ['18127']
# ['18105']
# Time to generate initial inequalities: 2.9 seconds.
# Adding non-dominated, minimal constraints:
# ['18019']
# ['18043']
# ['18081']
# ['18005']
# ['18085']
# ['18095']
# ['18063']
# ['18087', '18151', '18033']
# ['18167']
# ['18057']
# ['18089']
# ['18059']
# ['18157']
# ['18035']
# ['18163']
# ['18003']
# ['18141']
# ['18097']
# ['18091']
# ['18109']
# ['18039']
# ['18067']
# ['18127']
# ['18105']
# Time to generate initial inequalities: 3.14 seconds.
# Adding non-dominated, minimal constraints:
# ['18019']
# ['18043']
# ['18081']
# ['18005']
# ['18085']
# ['18095']
# ['18063']
# ['18087', '18151', '18033']
# ['18167']
# ['18057']
# ['18089']
# ['18059']
# ['18157']
# ['18035']
# ['18163']
# ['18003']
# ['18141']
# ['18097']
# ['18091']
# ['18109']
# ['18039']
# ['18067']
# ['18127']
# ['18105']
# Time to generate initial inequalities: 3.16 seconds.
# Adding non-dominated, minimal constraints:
# ['18019']
# ['18043']
# ['18081']
# ['18005']
# ['18085']
# ['18095']
# ['18063']
# ['18087', '18151', '18033']
# ['18167']
# ['18057']
# ['18089']
# ['18059']
# ['18157']
# ['18035']
# ['18163']
# ['18003']
# ['18141']
# ['18097']
# ['18091']
# ['18109']
# ['18039']
# ['18067']
# ['18127']
# ['18105']
# Time to generate initial inequalities: 5.08 seconds.
# Starting KS with k = 4 and deviation = 0.01
# Thus, we have L = 730798 and U = 738142
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 3.2 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 3.46 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 3.47 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 3.31 seconds.
# Starting KS with k = 40 and deviation = 0.1
# Thus, we have L = 69775 and U = 77119
# Adding non-dominated, minimal constraints:
# ['20045']
# ['20173']
# ['20103']
# ['20177']
# ['20209']
# ['20091']
# Time to generate initial inequalities: 3.66 seconds.
# Adding non-dominated, minimal constraints:
# ['20045']
# ['20173']
# ['20103']
# ['20177']
# ['20209']
# ['20091']
# Time to generate initial inequalities: 3.52 seconds.
# Adding non-dominated, minimal constraints:
# ['20045']
# ['20173']
# ['20103']
# ['20177']
# ['20209']
# ['20091']
# Time to generate initial inequalities: 3.74 seconds.
# Adding non-dominated, minimal constraints:
# ['20045']
# ['20173']
# ['20103']
# ['20177']
# ['20209']
# ['20091']
# Time to generate initial inequalities: 4.06 seconds.
# Starting KS with k = 125 and deviation = 0.1
# Thus, we have L = 22328 and U = 24678
# Adding non-dominated, minimal constraints:
# ['20079']
# ['20055']
# ['20045']
# ['20173']
# ['20113']
# ['20149']
# ['20057']
# ['20103']
# ['20177']
# ['20111']
# ['20155']
# ['20035']
# ['20051']
# ['20015']
# ['20161']
# ['20009']
# ['20125']
# ['20037']
# ['20209']
# ['20061']
# ['20081', '20189', '20119', '20175']
# ['20091']
# ['20059']
# ['20169']
# ['20121']
# Time to generate initial inequalities: 3.9 seconds.
# Adding non-dominated, minimal constraints:
# ['20079']
# ['20055']
# ['20045']
# ['20173']
# ['20113']
# ['20149']
# ['20057']
# ['20103']
# ['20177']
# ['20111']
# ['20155']
# ['20035']
# ['20051']
# ['20015']
# ['20161']
# ['20009']
# ['20125']
# ['20037']
# ['20209']
# ['20061']
# ['20081', '20189', '20119', '20175']
# ['20091']
# ['20059']
# ['20169']
# ['20121']
# Time to generate initial inequalities: 3.91 seconds.
# Adding non-dominated, minimal constraints:
# ['20079']
# ['20055']
# ['20045']
# ['20173']
# ['20113']
# ['20149']
# ['20057']
# ['20103']
# ['20177']
# ['20111']
# ['20155']
# ['20035']
# ['20051']
# ['20015']
# ['20161']
# ['20009']
# ['20125']
# ['20037']
# ['20209']
# ['20061']
# ['20081', '20189', '20119', '20175']
# ['20091']
# ['20059']
# ['20169']
# ['20121']
# Time to generate initial inequalities: 3.63 seconds.
# Adding non-dominated, minimal constraints:
# ['20079']
# ['20055']
# ['20045']
# ['20173']
# ['20113']
# ['20149']
# ['20057']
# ['20103']
# ['20177']
# ['20111']
# ['20155']
# ['20035']
# ['20051']
# ['20015']
# ['20161']
# ['20009']
# ['20125']
# ['20037']
# ['20209']
# ['20061']
# ['20081', '20189', '20119', '20175']
# ['20091']
# ['20059']
# ['20169']
# ['20121']
# Time to generate initial inequalities: 4.25 seconds.
# Starting KY with k = 6 and deviation = 0.01
# Thus, we have L = 747218 and U = 754727
# Adding non-dominated, minimal constraints:
# ['21111']
# Time to generate initial inequalities: 39.08 seconds.
# Adding non-dominated, minimal constraints:
# ['21111']
# Time to generate initial inequalities: 39.64 seconds.
# Adding non-dominated, minimal constraints:
# ['21111']
# Time to generate initial inequalities: 41.57 seconds.
# Adding non-dominated, minimal constraints:
# ['21111']
# Time to generate initial inequalities: 42.72 seconds.
# Starting KY with k = 38 and deviation = 0.1
# Thus, we have L = 112646 and U = 124503
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21067']
# ['21227']
# ['21111']
# ['21117']
# Time to generate initial inequalities: 6.41 seconds.
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21067']
# ['21227']
# ['21111']
# ['21117']
# Time to generate initial inequalities: 6.17 seconds.
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21067']
# ['21227']
# ['21111']
# ['21117']
# Time to generate initial inequalities: 6.48 seconds.
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21067']
# ['21227']
# ['21111']
# ['21117']
# Time to generate initial inequalities: 7.02 seconds.
# Starting KY with k = 100 and deviation = 0.1
# Thus, we have L = 42806 and U = 47311
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21029']
# ['21095', '21133', '21131', '21013', '21193', '21051']
# ['21151']
# ['21035', '21083', '21157', '21221']
# ['21037']
# ['21059']
# ['21019']
# ['21113']
# ['21185']
# ['21211']
# ['21111']
# ['21145']
# ['21047']
# ['21067']
# ['21227']
# ['21073']
# ['21195']
# ['21125']
# ['21199']
# ['21093']
# ['21117']
# ['21209']
# Time to generate initial inequalities: 7.64 seconds.
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21029']
# ['21095', '21133', '21131', '21013', '21193', '21051']
# ['21151']
# ['21035', '21083', '21157', '21221']
# ['21037']
# ['21059']
# ['21019']
# ['21113']
# ['21185']
# ['21211']
# ['21111']
# ['21145']
# ['21047']
# ['21067']
# ['21227']
# ['21073']
# ['21195']
# ['21125']
# ['21199']
# ['21093']
# ['21117']
# ['21209']
# Time to generate initial inequalities: 8.16 seconds.
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21029']
# ['21095', '21133', '21131', '21013', '21193', '21051']
# ['21151']
# ['21035', '21083', '21157', '21221']
# ['21037']
# ['21059']
# ['21019']
# ['21113']
# ['21185']
# ['21211']
# ['21111']
# ['21145']
# ['21047']
# ['21067']
# ['21227']
# ['21073']
# ['21195']
# ['21125']
# ['21199']
# ['21093']
# ['21117']
# ['21209']
# Time to generate initial inequalities: 7.98 seconds.
# Adding non-dominated, minimal constraints:
# ['21015']
# ['21029']
# ['21095', '21133', '21131', '21013', '21193', '21051']
# ['21151']
# ['21035', '21083', '21157', '21221']
# ['21037']
# ['21059']
# ['21019']
# ['21113']
# ['21185']
# ['21211']
# ['21111']
# ['21145']
# ['21047']
# ['21067']
# ['21227']
# ['21073']
# ['21195']
# ['21125']
# ['21199']
# ['21093']
# ['21117']
# ['21209']
# Time to generate initial inequalities: 13.6 seconds.
# Starting LA with k = 6 and deviation = 0.01
# Thus, we have L = 772412 and U = 780174
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.48 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.44 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.49 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 1.56 seconds.
# Starting LA with k = 39 and deviation = 0.1
# Thus, we have L = 113459 and U = 125401
# Adding non-dominated, minimal constraints:
# ['22103']
# ['22005']
# ['22063']
# ['22051']
# ['22079']
# ['22105']
# ['22055']
# ['22019']
# ['22071']
# ['22015']
# ['22073']
# ['22033']
# ['22017']
# ['22007', '22101', '22109', '22057']
# Time to generate initial inequalities: 1.86 seconds.
# Adding non-dominated, minimal constraints:
# ['22103']
# ['22005']
# ['22063']
# ['22051']
# ['22079']
# ['22105']
# ['22055']
# ['22019']
# ['22071']
# ['22015']
# ['22073']
# ['22033']
# ['22017']
# ['22007', '22101', '22109', '22057']
# Time to generate initial inequalities: 1.69 seconds.
# Adding non-dominated, minimal constraints:
# ['22103']
# ['22005']
# ['22063']
# ['22051']
# ['22079']
# ['22105']
# ['22055']
# ['22019']
# ['22071']
# ['22015']
# ['22073']
# ['22033']
# ['22017']
# ['22007', '22101', '22109', '22057']
# Time to generate initial inequalities: 1.83 seconds.
# Adding non-dominated, minimal constraints:
# ['22103']
# ['22005']
# ['22063']
# ['22051']
# ['22079']
# ['22105']
# ['22055']
# ['22019']
# ['22071']
# ['22015']
# ['22073']
# ['22033']
# ['22017']
# ['22007', '22101', '22109', '22057']
# Time to generate initial inequalities: 1.82 seconds.
# Starting LA with k = 105 and deviation = 0.1
# Thus, we have L = 42142 and U = 46577
# Adding non-dominated, minimal constraints:
# ['22101']
# ['22061']
# ['22079']
# ['22019']
# ['22071']
# ['22017']
# ['22103']
# ['22005']
# ['22001']
# ['22099']
# ['22109']
# ['22055']
# ['22045']
# ['22057']
# ['22073']
# ['22113']
# ['22063']
# ['22051']
# ['22097']
# ['22105']
# ['22015']
# ['22115']
# ['22089']
# ['22033']
# ...
# Adding non-dominated, minimal constraints:
# ['51059']
# ['51087']
# ['51041']
# ['51760']
# ['51013']
# ['51810']
# ['51710']
# ['51550']
# ['51107']
# ['51153']
# Time to generate initial inequalities: 6.72 seconds.
# Adding non-dominated, minimal constraints:
# ['51059']
# ['51087']
# ['51041']
# ['51760']
# ['51013']
# ['51810']
# ['51710']
# ['51550']
# ['51107']
# ['51153']
# Time to generate initial inequalities: 7.43 seconds.
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# Dropped 1 and reduced from {'51143', '51590'} to ['51143'].
# Dropped 1 and reduced from {'51015', '51790'} to ['51015'].
# Dropped 1 and reduced from {'51165', '51660'} to ['51165'].
# Dropped 1 and reduced from {'51015', '51820'} to ['51015'].
# Adding non-dominated, minimal constraints:
# ['51059']
# ['51041']
# ['51161']
# ['51143']
# ['51710']
# ['51510']
# ['51087']
# ['51003']
# ['51121']
# ['51760']
# ['51810']
# ['51650']
# ['51550']
# ['51800']
# ['51085']
# ['51107']
# ['51153']
# ['51015']
# ['51009', '51031', '51019', '51680']
# ['51770']
# ['51013']
# ['51740']
# ['51177']
# ['51165']
# ['51069']
# ['51700']
# ['51015']
# ['51179']
# Time to generate initial inequalities: 7.68 seconds.
# Dropped 1 and reduced from {'51143', '51590'} to ['51143'].
# Dropped 1 and reduced from {'51015', '51790'} to ['51015'].
# Dropped 1 and reduced from {'51165', '51660'} to ['51165'].
# Dropped 1 and reduced from {'51015', '51820'} to ['51015'].
# Adding non-dominated, minimal constraints:
# ['51059']
# ['51041']
# ['51161']
# ['51143']
# ['51710']
# ['51510']
# ['51087']
# ['51003']
# ['51121']
# ['51760']
# ['51810']
# ['51650']
# ['51550']
# ['51800']
# ['51085']
# ['51107']
# ['51153']
# ['51015']
# ['51009', '51031', '51019', '51680']
# ['51770']
# ['51013']
# ['51740']
# ['51177']
# ['51165']
# ['51069']
# ['51700']
# ['51015']
# ['51179']
# Time to generate initial inequalities: 7.68 seconds.
# Adding non-dominated, minimal constraints:
# ['51059']
# ['51041']
# ['51161']
# ['51710']
# ['51510']
# ['51087']
# ['51003']
# ['51121']
# ['51760']
# ['51810']
# ['51650']
# ['51550']
# ['51800']
# ['51085']
# ['51107']
# ['51153']
# ['51015']
# ['51143']
# ['51009', '51031', '51019', '51680']
# ['51770']
# ['51013']
# ['51740']
# ['51165']
# ['51177']
# ['51069']
# ['51700']
# ['51179']
# Time to generate initial inequalities: 7.54 seconds.
# Adding non-dominated, minimal constraints:
# ['51059']
# ['51041']
# ['51161']
# ['51710']
# ['51510']
# ['51087']
# ['51003']
# ['51121']
# ['51760']
# ['51810']
# ['51650']
# ['51550']
# ['51800']
# ['51085']
# ['51107']
# ['51153']
# ['51015']
# ['51143']
# ['51009', '51031', '51019', '51680']
# ['51770']
# ['51013']
# ['51740']
# ['51165']
# ['51177']
# ['51069']
# ['51700']
# ['51179']
# Time to generate initial inequalities: 8.46 seconds.
# Starting VT with k = 1 and deviation = 0.01
# Thus, we have L = 639862 and U = 646292
# Skipping VT CD because k = 1.
# Starting VT with k = 30 and deviation = 0.1
# Thus, we have L = 20365 and U = 22507
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50011']
# ['50007']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50011']
# ['50007']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50011']
# ['50007']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# Time to generate initial inequalities: 0.01 seconds.
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50011']
# ['50007']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# Time to generate initial inequalities: 0.01 seconds.
# Starting VT with k = 150 and deviation = 0.1
# Thus, we have L = 4073 and U = 4501
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50013']
# ['50007']
# ['50011']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# ['50009']
# Time to generate initial inequalities: 0.03 seconds.
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50013']
# ['50007']
# ['50011']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# ['50009']
# Time to generate initial inequalities: 0.02 seconds.
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50013']
# ['50007']
# ['50011']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# ['50009']
# Time to generate initial inequalities: 0.02 seconds.
# Adding non-dominated, minimal constraints:
# ['50023']
# ['50013']
# ['50007']
# ['50011']
# ['50021']
# ['50017']
# ['50015']
# ['50025']
# ['50001']
# ['50005']
# ['50019']
# ['50027']
# ['50003']
# ['50009']
# Time to generate initial inequalities: 0.02 seconds.
# Starting WA with k = 10 and deviation = 0.01
# Thus, we have L = 766676 and U = 774380
# Adding non-dominated, minimal constraints:
# ['53061']
# ['53053']
# ['53033']
# Time to generate initial inequalities: 1.08 seconds.
# Adding non-dominated, minimal constraints:
# ['53061']
# ['53053']
# ['53033']
# Time to generate initial inequalities: 1.05 seconds.
# Adding non-dominated, minimal constraints:
# ['53061']
# ['53053']
# ['53033']
# Time to generate initial inequalities: 1.0 seconds.
# Adding non-dominated, minimal constraints:
# ['53061']
# ['53053']
# ['53033']
# Time to generate initial inequalities: 1.03 seconds.
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 0.84 seconds.
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 0.83 seconds.
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 0.82 seconds.
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 0.88 seconds.
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 0.86 seconds.
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 0.88 seconds.
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 0.87 seconds.
# Adding non-dominated, minimal constraints:
# ['53067']
# ['53077']
# ['53033']
# ['53063']
# ['53073']
# ['53005']
# ['53053']
# ['53011']
# ['53035']
# ['53061']
# Time to generate initial inequalities: 1.0 seconds.
# Starting WI with k = 8 and deviation = 0.01
# Thus, we have L = 733032 and U = 740398
# Adding non-dominated, minimal constraints:
# ['55079']
# Time to generate initial inequalities: 2.33 seconds.
# Adding non-dominated, minimal constraints:
# ['55079']
# Time to generate initial inequalities: 2.24 seconds.
# Adding non-dominated, minimal constraints:
# ['55079']
# Time to generate initial inequalities: 2.33 seconds.
# Adding non-dominated, minimal constraints:
# ['55079']
# Time to generate initial inequalities: 2.25 seconds.
# Starting WI with k = 33 and deviation = 0.1
# Thus, we have L = 169668 and U = 187527
# Adding non-dominated, minimal constraints:
# ['55101']
# ['55087']
# ['55025']
# ['55079']
# ['55009']
# ['55133']
# Time to generate initial inequalities: 2.54 seconds.
# Adding non-dominated, minimal constraints:
# ['55101']
# ['55087']
# ['55025']
# ['55079']
# ['55009']
# ['55133']
# Time to generate initial inequalities: 2.42 seconds.
# Adding non-dominated, minimal constraints:
# ['55101']
# ['55087']
# ['55025']
# ['55079']
# ['55009']
# ['55133']
# Time to generate initial inequalities: 2.59 seconds.
# Adding non-dominated, minimal constraints:
# ['55101']
# ['55087']
# ['55025']
# ['55079']
# ['55009']
# ['55133']
# Time to generate initial inequalities: 2.78 seconds.
# Starting WI with k = 99 and deviation = 0.1
# Thus, we have L = 56556 and U = 62509
# Dropped 1 and reduced from {'55029', '55067', '55125', '55075', '55085', '55037', '55083', '55041'} to ['55029', '55067', '55125', '55075', '55085', '55083', '55041'].
# Adding non-dominated, minimal constraints:
# ['55111']
# ['55025']
# ['55055']
# ['55117']
# ['55035']
# ['55023', '55049', '55043', '55065', '55103']
# ['55087']
# ['55097']
# ['55079']
# ['55039']
# ['55089']
# ['55009']
# ['55109']
# ['55139']
# ['55131']
# ['55017']
# ['55141']
# ['55101']
# ['55073']
# ['55059']
# ['55133']
# ['55127']
# ['55027']
# ['55071']
# ['55105']
# ['55029', '55067', '55125', '55075', '55085', '55083', '55041']
# ['55063']
# Time to generate initial inequalities: 4.18 seconds.
# Dropped 1 and reduced from {'55029', '55067', '55125', '55075', '55085', '55037', '55083', '55041'} to ['55029', '55067', '55125', '55075', '55085', '55083', '55041'].
# Adding non-dominated, minimal constraints:
# ['55111']
# ['55025']
# ['55055']
# ['55117']
# ['55035']
# ['55023', '55049', '55043', '55065', '55103']
# ['55087']
# ['55097']
# ['55079']
# ['55039']
# ['55089']
# ['55009']
# ['55109']
# ['55139']
# ['55131']
# ['55017']
# ['55141']
# ['55101']
# ['55073']
# ['55059']
# ['55133']
# ['55127']
# ['55027']
# ['55071']
# ['55105']
# ['55029', '55067', '55125', '55075', '55085', '55083', '55041']
# ['55063']
# Time to generate initial inequalities: 3.76 seconds.
# Dropped 1 and reduced from {'55029', '55067', '55125', '55075', '55085', '55037', '55083', '55041'} to ['55029', '55067', '55125', '55075', '55085', '55083', '55041'].
# Adding non-dominated, minimal constraints:
# ['55111']
# ['55025']
# ['55055']
# ['55117']
# ['55035']
# ['55023', '55049', '55043', '55065', '55103']
# ['55087']
# ['55097']
# ['55079']
# ['55039']
# ['55089']
# ['55009']
# ['55109']
# ['55139']
# ['55131']
# ['55017']
# ['55141']
# ['55101']
# ['55073']
# ['55059']
# ['55133']
# ['55127']
# ['55027']
# ['55071']
# ['55105']
# ['55029', '55067', '55125', '55075', '55085', '55083', '55041']
# ['55063']
# Time to generate initial inequalities: 3.7 seconds.
# Dropped 1 and reduced from {'55029', '55067', '55125', '55075', '55085', '55037', '55083', '55041'} to ['55029', '55067', '55125', '55075', '55085', '55083', '55041'].
# Adding non-dominated, minimal constraints:
# ['55111']
# ['55025']
# ['55055']
# ['55117']
# ['55035']
# ['55023', '55049', '55043', '55065', '55103']
# ['55087']
# ['55097']
# ['55079']
# ['55039']
# ['55089']
# ['55009']
# ['55109']
# ['55139']
# ['55131']
# ['55017']
# ['55141']
# ['55101']
# ['55073']
# ['55059']
# ['55133']
# ['55127']
# ['55027']
# ['55071']
# ['55105']
# ['55029', '55067', '55125', '55075', '55085', '55083', '55041']
# ['55063']
# Time to generate initial inequalities: 4.56 seconds.
# Starting WV with k = 2 and deviation = 0.01
# Thus, we have L = 892374 and U = 901342
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.77 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.78 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.78 seconds.
# Adding non-dominated, minimal constraints:
# Time to generate initial inequalities: 0.81 seconds.
# Starting WV with k = 17 and deviation = 0.1
# Thus, we have L = 100238 and U = 110788
# Dropped 3 and reduced from {'54009', '54029', '54051', '54069'} to ['54051'].
# Adding non-dominated, minimal constraints:
# ['54039']
# ['54003']
# ['54051']
# ['54011', '54099', '54079', '54053', '54043']
# Time to generate initial inequalities: 2.03 seconds.
# Dropped 3 and reduced from {'54009', '54029', '54051', '54069'} to ['54051'].
# Adding non-dominated, minimal constraints:
# ['54039']
# ['54003']
# ['54051']
# ['54011', '54099', '54079', '54053', '54043']
# Time to generate initial inequalities: 2.0 seconds.
# Adding non-dominated, minimal constraints:
# ['54039']
# ['54051']
# ['54003']
# ['54011', '54099', '54079', '54053', '54043']
# Time to generate initial inequalities: 2.44 seconds.
# Adding non-dominated, minimal constraints:
# ['54039']
# ['54051']
# ['54003']
# ['54011', '54099', '54079', '54053', '54043']
# Time to generate initial inequalities: 2.44 seconds.
# Starting WV with k = 100 and deviation = 0.1
# Thus, we have L = 17041 and U = 18834
# Adding non-dominated, minimal constraints:
# ['54099']
# ['54051']
# ['54027']
# ['54035']
# ['54043']
# ['54079']
# ['54053']
# ['54077']
# ['54039']
# ['54059']
# ['54045']
# ['54097']
# ['54025']
# ['54055']
# ['54047']
# ['54005']
# ['54029']
# ['54067']
# ['54009']
# ['54061']
# ['54109']
# ['54107']
# ['54033']
# ['54019']
# ['54057']
# ['54003']
# ['54069']
# ['54081']
# ['54049']
# ['54011']
# ['54083']
# ['54037']
# Time to generate initial inequalities: 0.24 seconds.
# Adding non-dominated, minimal constraints:
# ['54099']
# ['54051']
# ['54027']
# ['54035']
# ['54043']
# ['54079']
# ['54053']
# ['54077']
# ['54039']
# ['54059']
# ['54045']
# ['54097']
# ['54025']
# ['54055']
# ['54047']
# ['54005']
# ['54029']
# ['54067']
# ['54009']
# ['54061']
# ['54109']
# ['54107']
# ['54033']
# ['54019']
# ['54057']
# ['54003']
# ['54069']
# ['54081']
# ['54049']
# ['54011']
# ['54083']
# ['54037']
# Time to generate initial inequalities: 0.31 seconds.
# Adding non-dominated, minimal constraints:
# ['54099']
# ['54051']
# ['54027']
# ['54035']
# ['54043']
# ['54079']
# ['54053']
# ['54077']
# ['54039']
# ['54059']
# ['54045']
# ['54097']
# ['54025']
# ['54055']
# ['54047']
# ['54005']
# ['54029']
# ['54067']
# ['54009']
# ['54061']
# ['54109']
# ['54107']
# ['54033']
# ['54019']
# ['54057']
# ['54003']
# ['54069']
# ['54081']
# ['54049']
# ['54011']
# ['54083']
# ['54037']
# Time to generate initial inequalities: 0.34 seconds.
# Adding non-dominated, minimal constraints:
# ['54099']
# ['54051']
# ['54027']
# ['54035']
# ['54043']
# ['54079']
# ['54053']
# ['54077']
# ['54039']
# ['54059']
# ['54045']
# ['54097']
# ['54025']
# ['54055']
# ['54047']
# ['54005']
# ['54029']
# ['54067']
# ['54009']
# ['54061']
# ['54109']
# ['54107']
# ['54033']
# ['54019']
# ['54057']
# ['54003']
# ['54069']
# ['54081']
# ['54049']
# ['54011']
# ['54083']
# ['54037']
# Time to generate initial inequalities: 0.48 seconds.
# Starting WY with k = 1 and deviation = 0.01
# Thus, we have L = 573967 and U = 579735
# Skipping WY CD because k = 1.
# Starting WY with k = 31 and deviation = 0.1
# Thus, we have L = 17678 and U = 19538
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56037']
# ['56021']
# ['56039']
# ['56001']
# ['56013']
# Time to generate initial inequalities: 0.05 seconds.
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56037']
# ['56021']
# ['56039']
# ['56001']
# ['56013']
# Time to generate initial inequalities: 0.06 seconds.
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56037']
# ['56021']
# ['56039']
# ['56001']
# ['56013']
# Time to generate initial inequalities: 0.06 seconds.
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56037']
# ['56021']
# ['56039']
# ['56001']
# ['56013']
# Time to generate initial inequalities: 0.07 seconds.
# Starting WY with k = 62 and deviation = 0.1
# Thus, we have L = 8839 and U = 9769
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56009']
# ['56037']
# ['56007']
# ['56021']
# ['56039']
# ['56015']
# ['56001']
# ['56013']
# ['56003']
# Time to generate initial inequalities: 0.05 seconds.
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56009']
# ['56037']
# ['56007']
# ['56021']
# ['56039']
# ['56015']
# ['56001']
# ['56013']
# ['56003']
# Time to generate initial inequalities: 0.05 seconds.
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56009']
# ['56037']
# ['56007']
# ['56021']
# ['56039']
# ['56015']
# ['56001']
# ['56013']
# ['56003']
# Time to generate initial inequalities: 0.05 seconds.
# Adding non-dominated, minimal constraints:
# ['56041']
# ['56023']
# ['56029']
# ['56005']
# ['56033']
# ['56025']
# ['56009']
# ['56037']
# ['56007']
# ['56021']
# ['56039']
# ['56015']
# ['56001']
# ['56013']
# ['56003']
# Time to generate initial inequalities: 0.07 seconds.

# %%
print("results =", results)
# Out:
# results = {('AK', 'SS'): {'k': 20, 'L': 34837, 'U': 38503, '|C|': 30, 'm': 55, 'trivial_UB': 26, 'vicinity_constraints': [['02020'], ['02090'], ['02122'], ['02170']], 'vicinity_UB': 26, 'generalized_vicinity_constraints': [['02020'], ['02090'], ['02122'], ['02170']], 'generalized_vicinity_UB': 26, 'articulation_constraints': [['02020'], ['02090'], ['02122'], ['02170']], 'articulation_UB': 26, 'vertex_cut_constraints': [['02020'], ['02090'], ['02122'], ['02170']], 'vertex_cut_UB': 26}, ('AK', 'SH'): {'k': 40, 'L': 17419, 'U': 19251, '|C|': 30, 'm': 55, 'trivial_UB': 25, 'vicinity_constraints': [['02122'], ['02170'], ['02198', '02195', '02130', '02275'], ['02090'], ['02110'], ['02020']], 'vicinity_UB': 24, 'generalized_vicinity_constraints': [['02122'], ['02170'], ['02198', '02195', '02130', '02275'], ['02090'], ['02110'], ['02020']], 'generalized_vicinity_UB': 24, 'articulation_constraints': [['02122'], ['02170'], ['02198', '02195', '02130', '02275'], ['02090'], ['02110'], ['02020']], 'articulation_UB': 24, 'vertex_cut_constraints': [['02122'], ['02170'], ['02198', '02195', '02130', '02275'], ['02090'], ['02110'], ['02020']], 'vertex_cut_UB': 24}, ('AL', 'CD'): {'k': 7, 'L': 714166, 'U': 721342, '|C|': 67, 'm': 171, 'trivial_UB': 67, 'vicinity_constraints': [], 'vicinity_UB': 67, 'generalized_vicinity_constraints': [], 'generalized_vicinity_UB': 67, 'articulation_constraints': [], 'articulation_UB': 67, 'vertex_cut_constraints': [], 'vertex_cut_UB': 67}, ('AL', 'SS'): {'k': 35, 'L': 136374, 'U': 150728, '|C|': 67, 'm': 171, 'trivial_UB': 59, 'vicinity_constraints': [['01081'], ['01073'], ['01097'], ['01003'], ['01117'], ['01089'], ['01101'], ['01125']], 'vicinity_UB': 59, 'generalized_vicinity_constraints': [['01081'], ['01073'], ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055'], ['01097'], ['01003'], ['01117'], ['01089'], ['01101'], ['01125']], 'generalized_vicinity_UB': 58, 'articulation_constraints': [['01081'], ['01073'], ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055'], ['01097'], ['01003'], ['01117'], ['01089'], ['01101'], ['01125']], 'articulation_UB': 58, 'vertex_cut_constraints': [['01081'], ['01073'], ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055'], ['01097'], ['01003'], ['01117'], ['01089'], ['01101'], ['01125']], 'vertex_cut_UB': 58}, ('AL', 'SH'): {'k': 105, 'L': 45458, 'U': 50242, '|C|': 67, 'm': 171, 'trivial_UB': 40, 'vicinity_constraints': [['01121'], ['01127'], ['01115'], ['01055'], ['01009'], ['01089'], ['01049'], ['01033'], ['01073'], ['01031'], ['01069'], ['01097'], ['01083'], ['01117'], ['01077'], ['01081'], ['01071'], ['01095'], ['01003'], ['01015'], ['01103'], ['01113'], ['01001'], ['01051'], ['01043'], ['01101'], ['01125']], 'vicinity_UB': 40, 'generalized_vicinity_constraints': [['01121'], ['01127'], ['01115'], ['01055'], ['01009'], ['01089'], ['01049'], ['01033'], ['01073'], ['01031'], ['01069'], ['01097'], ['01083'], ['01117'], ['01077'], ['01081'], ['01071'], ['01095'], ['01003'], ['01015'], ['01103'], ['01113'], ['01001'], ['01051'], ['01043'], ['01101'], ['01125']], 'generalized_vicinity_UB': 40, 'articulation_constraints': [['01121'], ['01127'], ['01115'], ['01055'], ['01009'], ['01089'], ['01049'], ['01033'], ['01073'], ['01031'], ['01069'], ['01097'], ['01083'], ['01117'], ['01077'], ['01081'], ['01071'], ['01095'], ['01003'], ['01015'], ['01103'], ['01113'], ['01001'], ['01051'], ['01043'], ['01101'], ['01125']], 'articulation_UB': 40, 'vertex_cut_constraints': [['01121'], ['01127'], ['01115'], ['01055'], ['01009'], ['01089'], ['01049'], ['01033'], ['01073'], ['01031'], ['01069'], ['01097'], ['01083'], ['01117'], ['01077'], ['01081'], ['01071'], ['01095'], ['01003'], ['01015'], ['01103'], ['01113'], ['01001'], ['01051'], ['01043'], ['01101'], ['01125']], 'vertex_cut_UB': 40}, ('AR', 'CD'): {'k': 4, 'L': 749117, 'U': 756645, '|C|': 75, 'm': 192, 'trivial_UB': 75, 'vicinity_constraints': [], 'vicin ...

# %%
for district_type in district_types:
    print("Results for", district_type)
    for state in states:
        if (state, district_type) in results.keys():
            print(state, '&', end=' ')
            print(results[state, district_type]['|C|'], "&", end=' ')
            print(results[state, district_type]['k'], "&", end=' ')
            print(results[state, district_type]['L'], "&", end=' ')
            print(results[state, district_type]['U'], "&", end=' ')
            print(results[state, district_type]['trivial_UB'], "&", end=' ')
            print(results[state, district_type]['vicinity_UB'], "&", end=' ')
            print(results[state, district_type]['generalized_vicinity_UB'], "&", end=' ')
            print(results[state, district_type]['articulation_UB'], "&", end=' ')
            print(results[state, district_type]['vertex_cut_UB'], "\\\\")
    print("")
# Out:
# Results for CD
# AL & 67 & 7 & 714166 & 721342 & 67 & 67 & 67 & 67 & 67 \\
# AR & 75 & 4 & 749117 & 756645 & 75 & 75 & 75 & 75 & 75 \\
# AZ & 15 & 9 & 790639 & 798584 & 13 & 13 & 13 & 13 & 13 \\
# LA & 64 & 105 & 42142 & 46577 & 40 & 40 & 40 & 40 & 40 \\
# MA & 14 & 160 & 41741 & 46133 & 2 & 2 & 2 & 2 & 2 \\
# MD & 24 & 47 & 124859 & 138001 & 13 & 12 & 12 & 12 & 12 \\
# ME & 16 & 151 & 8572 & 9473 & 0 & 0 & 0 & 0 & 0 \\
# MI & 83 & 110 & 87032 & 96192 & 62 & 62 & 62 & 62 & 62 \\
# MN & 87 & 134 & 40457 & 44715 & 65 & 64 & 64 & 64 & 64 \\
# MO & 115 & 163 & 35873 & 39648 & 87 & 86 & 86 & 86 & 86 \\
# MS & 82 & 122 & 23060 & 25486 & 46 & 46 & 46 & 46 & 46 \\
# MT & 56 & 100 & 10301 & 11384 & 37 & 36 & 36 & 36 & 36 \\
# NC & 100 & 120 & 82646 & 91344 & 70 & 68 & 68 & 68 & 68 \\
# ND & 53 & 47 & 15748 & 17405 & 45 & 45 & 44 & 44 & 44 \\
# NH & 10 & 400 & 3272 & 3616 & 0 & 0 & 0 & 0 & 0 \\
# NJ & 21 & 40 & 220614 & 243836 & 6 & 6 & 6 & 6 & 6 \\
# NM & 33 & 70 & 28738 & 31762 & 19 & 18 & 18 & 18 & 18 \\
# NV & 17 & 42 & 70224 & 77615 & 15 & 14 & 14 & 14 & 14 \\
# NY & 62 & 150 & 127942 & 141408 & 40 & 39 & 39 & 39 & 39 \\
# OH & 88 & 99 & 113228 & 125145 & 66 & 65 & 64 & 64 & 64 \\
# OK & 77 & 101 & 37242 & 41161 & 53 & 52 & 52 & 52 & 52 \\
# OR & 36 & 60 & 67090 & 74151 & 22 & 22 & 22 & 22 & 22 \\
# PA & 67 & 203 & 60851 & 67255 & 30 & 30 & 30 & 30 & 30 \\
# RI & 5 & 75 & 13901 & 15363 & 0 & 0 & 0 & 0 & 0 \\
# SC & 46 & 124 & 39214 & 43341 & 22 & 22 & 22 & 22 & 22 \\
# SD & 66 & 35 & 24067 & 26600 & 59 & 58 & 58 & 58 & 58 \\
# TN & 95 & 99 & 66317 & 73296 & 77 & 76 & 76 & 76 & 76 \\
# TX & 254 & 150 & 184589 & 204018 & 230 & 230 & 230 & 230 & 230 \\
# UT & 29 & 75 & 41441 & 45802 & 20 & 20 & 20 & 20 & 20 \\
# VA & 133 & 100 & 81999 & 90629 & 110 & 106 & 106 & 106 & 106 \\
# VT & 14 & 150 & 4073 & 4501 & 0 & 0 & 0 & 0 & 0 \\
# WA & 39 & 49 & 149389 & 165113 & 29 & 29 & 29 & 29 & 29 \\
# WI & 72 & 99 & 56556 & 62509 & 47 & 45 & 45 & 45 & 45 \\
# WV & 55 & 100 & 17041 & 18834 & 23 & 23 & 23 & 23 & 23 \\
# WY & 23 & 62 & 8839 & 9769 & 8 & 8 & 8 & 8 & 8 \\

# %%
for district_type in district_types:
    print("Results for", district_type)
    for state in states:
        if (state, district_type) in results.keys():
            
            print(state, '&', end=' ')
            print(results[state, district_type]['|C|'], "&", end=' ')
            print(results[state, district_type]['k'], "&", end=' ')
            print(results[state, district_type]['L'], "&", end=' ')
            print(results[state, district_type]['U'], "&", end=' ')

            ub1 = results[state, district_type]['trivial_UB']
            ub2 = results[state, district_type]['vicinity_UB']
            ub3 = results[state, district_type]['generalized_vicinity_UB']
            ub4 = results[state, district_type]['articulation_UB']
            ub5 = results[state, district_type]['vertex_cut_UB']

            ubs = [ub1, ub2, ub3, ub4, ub5]
            cheap_ub_index = 1 + min( i for i in range(5) if ubs[i] == ub5 )
            
            if cheap_ub_index == 1:
                print(f"\\textbf{ {ub1} } &", end=' ')
            else:
                print(ub1, "&", end=' ')
            
            if cheap_ub_index == 2:
                print(f"\\textbf{ {ub2} } &", end=' ')
            else:
                print(ub2, "&", end=' ')
                
            if cheap_ub_index == 3:
                print(f"\\textbf{ {ub3} } &", end=' ')
            else:
                print(ub3, "&", end=' ')

            if cheap_ub_index == 4:
                print(f"\\textbf{ {ub4} } &", end=' ')
            else:
                print(ub4, "&", end=' ')

            if cheap_ub_index == 5:
                print(f"\\textbf{ {ub5} } &  \\\\")
            else:
                print(ub5, "&  \\\\")
                
    print("")
# Out:
# Results for CD
# AL & 67 & 7 & 714166 & 721342 & \textbf{67} & 67 & 67 & 67 & 67 &  \\
# AR & 75 & 4 & 749117 & 756645 & \textbf{75} & 75 & 75 & 75 & 75 &  \\
# AZ & 15 & 9 & 790639 & 798584 & \textbf{13} & 13 & 13 & 13 & 13 &  \\
# CA & 58 & 52 & 756549 & 764152 & \textbf{43} & 43 & 43 & 43 & 43 &  \\
# CO & 64 & 8 & 718106 & 725322 & 63 & \textbf{62} & 62 & 62 & 62 &  \\
# CT & 8 & 5 & 717583 & 724794 & \textbf{5} & 5 & 5 & 5 & 5 &  \\
# FL & 67 & 28 & 765375 & 773067 & 60 & \textbf{58} & 58 & 58 & 58 &  \\
# GA & 159 & 14 & 761311 & 768961 & \textbf{157} & 157 & 157 & 157 & 157 &  \\
# IA & 99 & 4 & 793605 & 801580 & \textbf{99} & 99 & 99 & 99 & 99 &  \\
# ID & 44 & 2 & 914956 & 924150 & \textbf{44} & 44 & 44 & 44 & 44 &  \\
# IL & 102 & 17 & 749909 & 757445 & \textbf{100} & 100 & 100 & 100 & 100 &  \\
# IN & 92 & 9 & 750178 & 757717 & \textbf{91} & 91 & 91 & 91 & 91 &  \\
# KS & 105 & 4 & 730798 & 738142 & \textbf{105} & 105 & 105 & 105 & 105 &  \\
# KY & 120 & 6 & 747218 & 754727 & \textbf{119} & 119 & 119 & 119 & 119 &  \\
# LA & 64 & 6 & 772412 & 780174 & \textbf{64} & 64 & 64 & 64 & 64 &  \\
# MA & 14 & 9 & 777197 & 785007 & 10 & \textbf{9} & 9 & 9 & 9 &  \\
# MD & 24 & 8 & 768293 & 776013 & \textbf{21} & 21 & 21 & 21 & 21 &  \\
# ME & 16 & 2 & 677774 & 684585 & \textbf{16} & 16 & 16 & 16 & 16 &  \\
# MI & 83 & 13 & 771304 & 779055 & \textbf{80} & 80 & 80 & 80 & 80 &  \\
# MN & 87 & 8 & 709746 & 716878 & \textbf{86} & 86 & 86 & 86 & 86 &  \\
# MO & 115 & 8 & 765518 & 773210 & \textbf{114} & 114 & 114 & 114 & 114 &  \\
# MS & 82 & 4 & 736619 & 744021 & \textbf{82} & 82 & 82 & 82 & 82 &  \\
# MT & 56 & 2 & 539402 & 544823 & \textbf{56} & 56 & 56 & 56 & 56 &  \\
# NC & 100 & 14 & 741943 & 749398 & \textbf{98} & 98 & 98 & 98 & 98 &  \\
# NE & 93 & 3 & 650566 & 657103 & \textbf{93} & 93 & 93 & 93 & 93 &  \\
# NH & 10 & 2 & 685321 & 692208 & 10 & \textbf{9} & 9 & 9 & 9 &  \\
# NJ & 21 & 12 & 770213 & 777953 & 18 & \textbf{16} & 16 & 16 & 16 &  \\
# NM & 33 & 3 & 702312 & 709369 & \textbf{33} & 33 & 33 & 33 & 33 &  \\
# NV & 17 & 4 & 772273 & 780034 & \textbf{16} & 16 & 16 & 16 & 16 &  \\
# NY & 62 & 26 & 773087 & 780855 & 54 & \textbf{53} & 53 & 53 & 53 &  \\
# OH & 88 & 15 & 782697 & 790563 & \textbf{85} & 85 & 85 & 85 & 85 &  \\
# OK & 77 & 5 & 787912 & 795829 & \textbf{76} & 76 & 76 & 76 & 76 &  \\
# OR & 36 & 6 & 702679 & 709740 & \textbf{35} & 35 & 35 & 35 & 35 &  \\
# PA & 67 & 17 & 761041 & 768689 & 64 & \textbf{63} & 63 & 63 & 63 &  \\
# RI & 5 & 2 & 545947 & 551432 & \textbf{4} & 4 & 4 & 4 & 4 &  \\
# SC & 46 & 7 & 727548 & 734859 & \textbf{46} & 46 & 46 & 46 & 46 &  \\
# TN & 95 & 9 & 764032 & 771710 & 94 & \textbf{93} & 93 & 93 & 93 &  \\
# TX & 254 & 38 & 763153 & 770821 & \textbf{244} & 244 & 244 & 244 & 244 &  \\
# UT & 29 & 4 & 813815 & 821993 & \textbf{28} & 28 & 28 & 28 & 28 &  \\
# VA & 133 & 11 & 780749 & 788595 & \textbf{132} & 132 & 132 & 132 & 132 &  \\
# WA & 39 & 10 & 766676 & 774380 & \textbf{36} & 36 & 36 & 36 & 36 &  \\
# WI & 72 & 8 & 733032 & 740398 & \textbf{71} & 71 & 71 & 71 & 71 &  \\
# WV & 55 & 2 & 892374 & 901342 & \textbf{55} & 55 & 55 & 55 & 55 &  \\
#
# Results for SS
# AK & 30 & 20 & 34837 & 38503 & \textbf{26} & 26 & 26 & 26 & 26 &  \\
# AL & 67 & 35 & 136374 & 150728 & 59 & 59 & \textbf{58} & 58 & 58 &  \\
# AR & 75 & 35 & 81742 & 90345 & \textbf{67} & 67 & 67 & 67 & 67 &  \\
# AZ & 15 & 30 & 226465 & 250302 & \textbf{12} & 12 & 12 & 12 & 12 &  \\
# CA & 58 & 40 & 939033 & 1037878 & 49 & \textbf{48} & 48 & 48 & 48 &  \\
# CO & 64 & 35 & 156716 & 173211 & \textbf{55} & 55 & 55 & 55 & 55 &  \\
# CT & 8 & 36 & 95157 & 105173 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# DE & 3 & 21 & 44784 & 49497 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# FL & 67 & 40 & 511532 & 565377 & 57 & \textbf{56} & 56 & 56 & 56 &  \\
# GA & 159 & 56 & 181720 & 200848 & 147 & \textbf{146} & 146 & 146 & 146 &  \\
# IA & 99 & 50 & 60618 & 66997 & \textbf{89} & 89 & 89 & 89 & 89 &  \\
# ID & 44 & 35 & 49919 & 55173 & 38 & \textbf{36} & 36 & 36 & 36 &  \\
# IL & 102 & 59 & 206304 & 228019 & \textbf{93} & 93 & 93 & 93 & 93 &  \\
# IN & 92 & 50 & 128926 & 142496 & 81 & \textbf{80} & 80 & 80 & 80 &  \\
# KS & 105 & 40 & 69775 & 77119 & \textbf{99} & 99 & 99 & 99 & 99 &  \\
# KY & 120 & 38 & 112646 & 124503 & \textbf{115} & 115 & 115 & 115 & 115 &  \\
# LA & 64 & 39 & 113459 & 125401 & 51 & \textbf{50} & 50 & 50 & 50 &  \\
# MA & 14 & 40 & 166961 & 184535 & \textbf{5} & 5 & 5 & 5 & 5 &  \\
# MD & 24 & 47 & 124859 & 138001 & 13 & \textbf{12} & 12 & 12 & 12 &  \\
# ME & 16 & 35 & 36979 & 40870 & \textbf{7} & 7 & 7 & 7 & 7 &  \\
# MI & 83 & 38 & 251934 & 278452 & \textbf{75} & 75 & 75 & 75 & 75 &  \\
# MN & 87 & 67 & 80913 & 89430 & \textbf{75} & 75 & 75 & 75 & 75 &  \\
# MO & 115 & 34 & 171976 & 190078 & \textbf{108} & 108 & 108 & 108 & 108 &  \\
# MS & 82 & 52 & 54101 & 59795 & 71 & \textbf{70} & 70 & 70 & 70 &  \\
# MT & 56 & 50 & 20601 & 22768 & \textbf{47} & 47 & 47 & 47 & 47 &  \\
# NC & 100 & 50 & 198349 & 219227 & 89 & \textbf{88} & 88 & 88 & 88 &  \\
# ND & 53 & 47 & 15748 & 17405 & 45 & 45 & \textbf{44} & 44 & 44 &  \\
# NE & 93 & 49 & 38030 & 42032 & \textbf{88} & 88 & 88 & 88 & 88 &  \\
# NH & 10 & 24 & 54528 & 60266 & \textbf{3} & 3 & 3 & 3 & 3 &  \\
# NJ & 21 & 40 & 220614 & 243836 & \textbf{6} & 6 & 6 & 6 & 6 &  \\
# NM & 33 & 42 & 47897 & 52938 & \textbf{22} & 22 & 22 & 22 & 22 &  \\
# NV & 17 & 21 & 140447 & 155230 & \textbf{15} & 15 & 15 & 15 & 15 &  \\
# NY & 62 & 63 & 304623 & 336687 & \textbf{49} & 49 & 49 & 49 & 49 &  \\
# OH & 88 & 33 & 339682 & 375436 & \textbf{81} & 81 & 81 & 81 & 81 &  \\
# OK & 77 & 48 & 78363 & 86610 & \textbf{71} & 71 & 71 & 71 & 71 &  \\
# OR & 36 & 30 & 134180 & 148303 & 29 & \textbf{28} & 28 & 28 & 28 &  \\
# PA & 67 & 50 & 247052 & 273056 & \textbf{53} & 53 & 53 & 53 & 53 &  \\
# RI & 5 & 38 & 27435 & 30322 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# SC & 46 & 46 & 105707 & 116833 & \textbf{32} & 32 & 32 & 32 & 32 &  \\
# SD & 66 & 35 & 24067 & 26600 & 59 & \textbf{58} & 58 & 58 & 58 &  \\
# TN & 95 & 33 & 198949 & 219890 & \textbf{88} & 88 & 88 & 88 & 88 &  \\
# TX & 254 & 31 & 893169 & 987186 & \textbf{248} & 248 & 248 & 248 & 248 &  \\
# UT & 29 & 29 & 107174 & 118455 & \textbf{23} & 23 & 23 & 23 & 23 &  \\
# VA & 133 & 40 & 204996 & 226574 & \textbf{123} & 123 & 123 & 123 & 123 &  \\
# VT & 14 & 30 & 20365 & 22507 & \textbf{2} & 2 & 2 & 2 & 2 &  \\
# WA & 39 & 49 & 149389 & 165113 & \textbf{29} & 29 & 29 & 29 & 29 &  \\
# WI & 72 & 33 & 169668 & 187527 & \textbf{66} & 66 & 66 & 66 & 66 &  \\
# WV & 55 & 17 & 100238 & 110788 & 53 & \textbf{51} & 51 & 51 & 51 &  \\
# WY & 23 & 31 & 17678 & 19538 & \textbf{12} & 12 & 12 & 12 & 12 &  \\
#
# Results for SH
# AK & 30 & 40 & 17419 & 19251 & 25 & \textbf{24} & 24 & 24 & 24 &  \\
# AL & 67 & 105 & 45458 & 50242 & \textbf{40} & 40 & 40 & 40 & 40 &  \\
# AR & 75 & 100 & 28610 & 31621 & \textbf{53} & 53 & 53 & 53 & 53 &  \\
# AZ & 15 & 30 & 226465 & 250302 & \textbf{12} & 12 & 12 & 12 & 12 &  \\
# CA & 58 & 80 & 469517 & 518939 & \textbf{42} & 42 & 42 & 42 & 42 &  \\
# CO & 64 & 65 & 84386 & 93267 & \textbf{53} & 53 & 53 & 53 & 53 &  \\
# CT & 8 & 151 & 22687 & 25074 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# DE & 3 & 41 & 22938 & 25352 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# FL & 67 & 120 & 170511 & 188459 & 40 & 40 & 40 & \textbf{39} & 39 &  \\
# GA & 159 & 180 & 56536 & 62486 & \textbf{120} & 120 & 120 & 120 & 120 &  \\
# IA & 99 & 100 & 30309 & 33498 & 78 & 78 & \textbf{77} & 77 & 77 &  \\
# ID & 44 & 35 & 49919 & 55173 & 38 & \textbf{36} & 36 & 36 & 36 &  \\
# IL & 102 & 118 & 103152 & 114009 & \textbf{86} & 86 & 86 & 86 & 86 &  \\
# IN & 92 & 100 & 64463 & 71248 & 69 & \textbf{68} & 68 & 68 & 68 &  \\
# KS & 105 & 125 & 22328 & 24678 & 81 & \textbf{80} & 80 & 80 & 80 &  \\
# KY & 120 & 100 & 42806 & 47311 & 99 & \textbf{97} & 97 & 97 & 97 &  \\
# LA & 64 & 105 & 42142 & 46577 & \textbf{40} & 40 & 40 & 40 & 40 &  \\
# MA & 14 & 160 & 41741 & 46133 & \textbf{2} & 2 & 2 & 2 & 2 &  \\
# MD & 24 & 47 & 124859 & 138001 & 13 & \textbf{12} & 12 & 12 & 12 &  \\
# ME & 16 & 151 & 8572 & 9473 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# MI & 83 & 110 & 87032 & 96192 & \textbf{62} & 62 & 62 & 62 & 62 &  \\
# MN & 87 & 134 & 40457 & 44715 & 65 & \textbf{64} & 64 & 64 & 64 &  \\
# MO & 115 & 163 & 35873 & 39648 & 87 & \textbf{86} & 86 & 86 & 86 &  \\
# MS & 82 & 122 & 23060 & 25486 & \textbf{46} & 46 & 46 & 46 & 46 &  \\
# MT & 56 & 100 & 10301 & 11384 & 37 & \textbf{36} & 36 & 36 & 36 &  \\
# NC & 100 & 120 & 82646 & 91344 & 70 & \textbf{68} & 68 & 68 & 68 &  \\
# ND & 53 & 47 & 15748 & 17405 & 45 & 45 & \textbf{44} & 44 & 44 &  \\
# NH & 10 & 400 & 3272 & 3616 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# NJ & 21 & 40 & 220614 & 243836 & \textbf{6} & 6 & 6 & 6 & 6 &  \\
# NM & 33 & 70 & 28738 & 31762 & 19 & \textbf{18} & 18 & 18 & 18 &  \\
# NV & 17 & 42 & 70224 & 77615 & 15 & \textbf{14} & 14 & 14 & 14 &  \\
# NY & 62 & 150 & 127942 & 141408 & 40 & \textbf{39} & 39 & 39 & 39 &  \\
# OH & 88 & 99 & 113228 & 125145 & 66 & 65 & \textbf{64} & 64 & 64 &  \\
# OK & 77 & 101 & 37242 & 41161 & 53 & \textbf{52} & 52 & 52 & 52 &  \\
# OR & 36 & 60 & 67090 & 74151 & \textbf{22} & 22 & 22 & 22 & 22 &  \\
# PA & 67 & 203 & 60851 & 67255 & \textbf{30} & 30 & 30 & 30 & 30 &  \\
# RI & 5 & 75 & 13901 & 15363 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# SC & 46 & 124 & 39214 & 43341 & \textbf{22} & 22 & 22 & 22 & 22 &  \\
# SD & 66 & 35 & 24067 & 26600 & 59 & \textbf{58} & 58 & 58 & 58 &  \\
# TN & 95 & 99 & 66317 & 73296 & 77 & \textbf{76} & 76 & 76 & 76 &  \\
# TX & 254 & 150 & 184589 & 204018 & \textbf{230} & 230 & 230 & 230 & 230 &  \\
# UT & 29 & 75 & 41441 & 45802 & \textbf{20} & 20 & 20 & 20 & 20 &  \\
# VA & 133 & 100 & 81999 & 90629 & 110 & \textbf{106} & 106 & 106 & 106 &  \\
# VT & 14 & 150 & 4073 & 4501 & \textbf{0} & 0 & 0 & 0 & 0 &  \\
# WA & 39 & 49 & 149389 & 165113 & \textbf{29} & 29 & 29 & 29 & 29 &  \\
# WI & 72 & 99 & 56556 & 62509 & 47 & \textbf{45} & 45 & 45 & 45 &  \\
# WV & 55 & 100 & 17041 & 18834 & \textbf{23} & 23 & 23 & 23 & 23 &  \\
# WY & 23 & 62 & 8839 & 9769 & \textbf{8} & 8 & 8 & 8 & 8 &  \\

# %%
# Define a color palette (list of color hex codes or names)
color_palette = [
    #"#FF5733",  # Red-Orange
    "#3357FF",  # Blue
    "#F1C40F",  # Yellow
    "#9B59B6",  # Purple
    "#1ABC9C",  # Teal
    "#E67E22",  # Orange
    #"#2ECC71",  # Green
    #"#3498DB",  # Sky Blue
    "#E74C3C",   # Red
    "#33FF57"  # Lime Green
]

# %%
from minimalize import remove_supersets

# ad-hoc inequality for GA/SH says must split one of:
# Brooks 13027
# Colquitt 13071
# Cook 13075
# Grady 13131
# Mitchell 13205
# Thomas 13275
# Tift 13277
# Worth 13321
state = 'GA'
district_type = 'SH'
results[state, district_type]['vertex_cut_constraints'].append({'13027', '13071', '13075', '13131', '13205', '13275', '13277', '13321'})
results[state, district_type]['vertex_cut_constraints'] = [ list(s) for s in remove_supersets( results[state, district_type]['vertex_cut_constraints'] ) ]

# ad-hoc inequality for FL/CD says must split one of:
# Volusia 12127
# Lake 12069
# Sumter 12119
# Hernando 12053
# Pasco 12101
# Polk 12105
# Manatee 12081
state = 'FL'
district_type = 'CD'
results[state, district_type]['vertex_cut_constraints'].append({'12127', '12069', '12119', '12053', '12101', '12105', '12081'})
results[state, district_type]['vertex_cut_constraints'] = [ list(s) for s in remove_supersets( results[state, district_type]['vertex_cut_constraints'] ) ]

# %%
import geopandas as gpd
from shapely.ops import unary_union
import matplotlib.pyplot as plt

for state in states:

    # read graph
    filename = state + '_county.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    # read geodataframe
    filename = state + '_county.shp'
    gdf = gpd.read_file( filepath + filename )
    
    for district_type in district_types:

        (k, L, U) = get_k_L_U(G, state, district_type)
        if k <= 1:
            print(f"Skipping {state} {district_type} because k = {k}.")
            continue

        ax = gdf.plot(color='lightgrey', edgecolor='white', aspect=1)
        counter = 0

        for I in results[state, district_type]['vertex_cut_constraints']:
            
            # Filter the counties 
            selected = gdf[gdf['GEOID20'].isin(I)]
            
            # 1. Dissolve the selected counties into a single polygon
            dissolved = selected.dissolve()
            
            # 2. Get the exterior boundary (Jordan curve)
            border = dissolved.boundary
        
            if len(I) == 1: # singleton
                border.plot(ax=ax, color='green', linewidth=3)
            else:  # larger
                color = color_palette[counter] # 'red'
                border.plot(ax=ax, color=color, linewidth=3)
                counter += 1

        output_name = state + '_' + district_type + '_inequalities.png'
        plt.savefig(output_name, dpi=300)
# Out:
# Starting AK with k = 1 and deviation = 0.01
# Thus, we have L = 729725 and U = 737057
# Skipping AK CD because k = 1.
# Starting AK with k = 20 and deviation = 0.1
# Thus, we have L = 34837 and U = 38503
# Starting AK with k = 40 and deviation = 0.1
# Thus, we have L = 17419 and U = 19251
# Starting AL with k = 7 and deviation = 0.01
# Thus, we have L = 714166 and U = 721342
# Starting AL with k = 35 and deviation = 0.1
# Thus, we have L = 136374 and U = 150728
# Starting AL with k = 105 and deviation = 0.1
# Thus, we have L = 45458 and U = 50242
# Starting AR with k = 4 and deviation = 0.01
# Thus, we have L = 749117 and U = 756645
# Starting AR with k = 35 and deviation = 0.1
# Thus, we have L = 81742 and U = 90345
# Starting AR with k = 100 and deviation = 0.1
# Thus, we have L = 28610 and U = 31621
# Starting AZ with k = 9 and deviation = 0.01
# Thus, we have L = 790639 and U = 798584
# Starting AZ with k = 30 and deviation = 0.1
# Thus, we have L = 226465 and U = 250302
# Starting AZ with k = 30 and deviation = 0.1
# Thus, we have L = 226465 and U = 250302
# Starting CA with k = 52 and deviation = 0.01
# Thus, we have L = 756549 and U = 764152
# Starting CA with k = 40 and deviation = 0.1
# Thus, we have L = 939033 and U = 1037878
# Starting CA with k = 80 and deviation = 0.1
# Thus, we have L = 469517 and U = 518939
# Starting CO with k = 8 and deviation = 0.01
# Thus, we have L = 718106 and U = 725322
# Starting CO with k = 35 and deviation = 0.1
# Thus, we have L = 156716 and U = 173211
# Starting CO with k = 65 and deviation = 0.1
# Thus, we have L = 84386 and U = 93267
# Starting CT with k = 5 and deviation = 0.01
# Thus, we have L = 717583 and U = 724794
# Starting CT with k = 36 and deviation = 0.1
# Thus, we have L = 95157 and U = 105173
# Starting CT with k = 151 and deviation = 0.1
# Thus, we have L = 22687 and U = 25074
# Starting DE with k = 1 and deviation = 0.01
# Thus, we have L = 984999 and U = 994897
# Skipping DE CD because k = 1.
# Starting DE with k = 21 and deviation = 0.1
# Thus, we have L = 44784 and U = 49497
# C:\Users\buchanan\AppData\Local\anaconda3\Lib\site-packages\geopandas\plotting.py:673: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=figsize)
# Starting DE with k = 41 and deviation = 0.1
# Thus, we have L = 22938 and U = 25352
# Starting FL with k = 28 and deviation = 0.01
# Thus, we have L = 765375 and U = 773067
# Starting FL with k = 40 and deviation = 0.1
# Thus, we have L = 511532 and U = 565377
# Starting FL with k = 120 and deviation = 0.1
# Thus, we have L = 170511 and U = 188459
# Starting GA with k = 14 and deviation = 0.01
# Thus, we have L = 761311 and U = 768961
# Starting GA with k = 56 and deviation = 0.1
# Thus, we have L = 181720 and U = 200848
# Starting GA with k = 180 and deviation = 0.1
# Thus, we have L = 56536 and U = 62486
# Starting IA with k = 4 and deviation = 0.01
# Thus, we have L = 793605 and U = 801580
# Starting IA with k = 50 and deviation = 0.1
# Thus, we have L = 60618 and U = 66997
# Starting IA with k = 100 and deviation = 0.1
# Thus, we have L = 30309 and U = 33498
# Starting ID with k = 2 and deviation = 0.01
# Thus, we have L = 914956 and U = 924150
# Starting ID with k = 35 and deviation = 0.1
# Thus, we have L = 49919 and U = 55173
# Starting ID with k = 35 and deviation = 0.1
# Thus, we have L = 49919 and U = 55173
# Starting IL with k = 17 and deviation = 0.01
# Thus, we have L = 749909 and U = 757445
# Starting IL with k = 59 and deviation = 0.1
# Thus, we have L = 206304 and U = 228019
# Starting IL with k = 118 and deviation = 0.1
# Thus, we have L = 103152 and U = 114009
# Starting IN with k = 9 and deviation = 0.01
# Thus, we have L = 750178 and U = 757717
# Starting IN with k = 50 and deviation = 0.1
# Thus, we have L = 128926 and U = 142496
# Starting IN with k = 100 and deviation = 0.1
# Thus, we have L = 64463 and U = 71248
# Starting KS with k = 4 and deviation = 0.01
# Thus, we have L = 730798 and U = 738142
# Starting KS with k = 40 and deviation = 0.1
# Thus, we have L = 69775 and U = 77119
# Starting KS with k = 125 and deviation = 0.1
# Thus, we have L = 22328 and U = 24678
# Starting KY with k = 6 and deviation = 0.01
# Thus, we have L = 747218 and U = 754727
# Starting KY with k = 38 and deviation = 0.1
# Thus, we have L = 112646 and U = 124503
# Starting KY with k = 100 and deviation = 0.1
# Thus, we have L = 42806 and U = 47311
# Starting LA with k = 6 and deviation = 0.01
# Thus, we have L = 772412 and U = 780174
# Starting LA with k = 39 and deviation = 0.1
# Thus, we have L = 113459 and U = 125401
# Starting LA with k = 105 and deviation = 0.1
# Thus, we have L = 42142 and U = 46577
# Starting MA with k = 9 and deviation = 0.01
# Thus, we have L = 777197 and U = 785007
# Starting MA with k = 40 and deviation = 0.1
# Thus, we have L = 166961 and U = 184535
# Starting MA with k = 160 and deviation = 0.1
# Thus, we have L = 41741 and U = 46133
# Starting MD with k = 8 and deviation = 0.01
# Thus, we have L = 768293 and U = 776013
# Starting MD with k = 47 and deviation = 0.1
# Thus, we have L = 124859 and U = 138001
# Starting MD with k = 47 and deviation = 0.1
# Thus, we have L = 124859 and U = 138001
# Starting ME with k = 2 and deviation = 0.01
# Thus, we have L = 677774 and U = 684585
# Starting ME with k = 35 and deviation = 0.1
# Thus, we have L = 36979 and U = 40870
# Starting ME with k = 151 and deviation = 0.1
# Thus, we have L = 8572 and U = 9473
# Starting MI with k = 13 and deviation = 0.01
# Thus, we have L = 771304 and U = 779055
# Starting MI with k = 38 and deviation = 0.1
# Thus, we have L = 251934 and U = 278452
# Starting MI with k = 110 and deviation = 0.1
# Thus, we have L = 87032 and U = 96192
# Starting MN with k = 8 and deviation = 0.01
# Thus, we have L = 709746 and U = 716878
# Starting MN with k = 67 and deviation = 0.1
# Thus, we have L = 80913 and U = 89430
# Starting MN with k = 134 and deviation = 0.1
# Thus, we have L = 40457 and U = 44715
# Starting MO with k = 8 and deviation = 0.01
# Thus, we have L = 765518 and U = 773210
# Starting MO with k = 34 and deviation = 0.1
# Thus, we have L = 171976 and U = 190078
# Starting MO with k = 163 and deviation = 0.1
# Thus, we have L = 35873 and U = 39648
# Starting MS with k = 4 and deviation = 0.01
# Thus, we have L = 736619 and U = 744021
# Starting MS with k = 52 and deviation = 0.1
# Thus, we have L = 54101 and U = 59795
# Starting MS with k = 122 and deviation = 0.1
# Thus, we have L = 23060 and U = 25486
# Starting MT with k = 2 and deviation = 0.01
# Thus, we have L = 539402 and U = 544823
# Starting MT with k = 50 and deviation = 0.1
# Thus, we have L = 20601 and U = 22768
# Starting MT with k = 100 and deviation = 0.1
# Thus, we have L = 10301 and U = 11384
# Starting NC with k = 14 and deviation = 0.01
# Thus, we have L = 741943 and U = 749398
# Starting NC with k = 50 and deviation = 0.1
# Thus, we have L = 198349 and U = 219227
# Starting NC with k = 120 and deviation = 0.1
# Thus, we have L = 82646 and U = 91344
# Starting ND with k = 1 and deviation = 0.01
# Thus, we have L = 775199 and U = 782989
# Skipping ND CD because k = 1.
# Starting ND with k = 47 and deviation = 0.1
# Thus, we have L = 15748 and U = 17405
# Starting ND with k = 47 and deviation = 0.1
# Thus, we have L = 15748 and U = 17405
# Starting NE with k = 3 and deviation = 0.01
# Thus, we have L = 650566 and U = 657103
# Starting NE with k = 49 and deviation = 0.1
# Thus, we have L = 38030 and U = 42032
# Starting NE with k = 0 and deviation = 0.1
# Thus, we have L = 0 and U = 0
# Skipping NE SH because k = 0.
# Starting NH with k = 2 and deviation = 0.01
# Thus, we have L = 685321 and U = 692208
# Starting NH with k = 24 and deviation = 0.1
# Thus, we have L = 54528 and U = 60266
# Starting NH with k = 400 and deviation = 0.1
# Thus, we have L = 3272 and U = 3616
# Starting NJ with k = 12 and deviation = 0.01
# Thus, we have L = 770213 and U = 777953
# Starting NJ with k = 40 and deviation = 0.1
# Thus, we have L = 220614 and U = 243836
# Starting NJ with k = 40 and deviation = 0.1
# Thus, we have L = 220614 and U = 243836
# Starting NM with k = 3 and deviation = 0.01
# Thus, we have L = 702312 and U = 709369
# Starting NM with k = 42 and deviation = 0.1
# Thus, we have L = 47897 and U = 52938
# Starting NM with k = 70 and deviation = 0.1
# Thus, we have L = 28738 and U = 31762
# Starting NV with k = 4 and deviation = 0.01
# Thus, we have L = 772273 and U = 780034
# Starting NV with k = 21 and deviation = 0.1
# Thus, we have L = 140447 and U = 155230
# Starting NV with k = 42 and deviation = 0.1
# Thus, we have L = 70224 and U = 77615
# Starting NY with k = 26 and deviation = 0.01
# Thus, we have L = 773087 and U = 780855
# Starting NY with k = 63 and deviation = 0.1
# Thus, we have L = 304623 and U = 336687
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# Starting OH with k = 15 and deviation = 0.01
# Thus, we have L = 782697 and U = 790563
# Starting OH with k = 33 and deviation = 0.1
# Thus, we have L = 339682 and U = 375436
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# Starting OK with k = 5 and deviation = 0.01
# Thus, we have L = 787912 and U = 795829
# Starting OK with k = 48 and deviation = 0.1
# Thus, we have L = 78363 and U = 86610
# Starting OK with k = 101 and deviation = 0.1
# Thus, we have L = 37242 and U = 41161
# Starting OR with k = 6 and deviation = 0.01
# Thus, we have L = 702679 and U = 709740
# Starting OR with k = 30 and deviation = 0.1
# Thus, we have L = 134180 and U = 148303
# Starting OR with k = 60 and deviation = 0.1
# Thus, we have L = 67090 and U = 74151
# Starting PA with k = 17 and deviation = 0.01
# Thus, we have L = 761041 and U = 768689
# Starting PA with k = 50 and deviation = 0.1
# Thus, we have L = 247052 and U = 273056
# Starting PA with k = 203 and deviation = 0.1
# Thus, we have L = 60851 and U = 67255
# Starting RI with k = 2 and deviation = 0.01
# Thus, we have L = 545947 and U = 551432
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# Starting RI with k = 75 and deviation = 0.1
# Thus, we have L = 13901 and U = 15363
# Starting SC with k = 7 and deviation = 0.01
# Thus, we have L = 727548 and U = 734859
# Starting SC with k = 46 and deviation = 0.1
# Thus, we have L = 105707 and U = 116833
# Starting SC with k = 124 and deviation = 0.1
# Thus, we have L = 39214 and U = 43341
# Starting SD with k = 1 and deviation = 0.01
# Thus, we have L = 882234 and U = 891100
# Skipping SD CD because k = 1.
# Starting SD with k = 35 and deviation = 0.1
# Thus, we have L = 24067 and U = 26600
# Starting SD with k = 35 and deviation = 0.1
# Thus, we have L = 24067 and U = 26600
# Starting TN with k = 9 and deviation = 0.01
# Thus, we have L = 764032 and U = 771710
# Starting TN with k = 33 and deviation = 0.1
# Thus, we have L = 198949 and U = 219890
# Starting TN with k = 99 and deviation = 0.1
# Thus, we have L = 66317 and U = 73296
# Starting TX with k = 38 and deviation = 0.01
# Thus, we have L = 763153 and U = 770821
# Starting TX with k = 31 and deviation = 0.1
# Thus, we have L = 893169 and U = 987186
# Starting TX with k = 150 and deviation = 0.1
# Thus, we have L = 184589 and U = 204018
# Starting UT with k = 4 and deviation = 0.01
# Thus, we have L = 813815 and U = 821993
# Starting UT with k = 29 and deviation = 0.1
# Thus, we have L = 107174 and U = 118455
# Starting UT with k = 75 and deviation = 0.1
# Thus, we have L = 41441 and U = 45802
# Starting VA with k = 11 and deviation = 0.01
# Thus, we have L = 780749 and U = 788595
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# Starting VT with k = 1 and deviation = 0.01
# Thus, we have L = 639862 and U = 646292
# Skipping VT CD because k = 1.
# Starting VT with k = 30 and deviation = 0.1
# Thus, we have L = 20365 and U = 22507
# Starting VT with k = 150 and deviation = 0.1
# Thus, we have L = 4073 and U = 4501
# Starting WA with k = 10 and deviation = 0.01
# Thus, we have L = 766676 and U = 774380
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# Starting WI with k = 8 and deviation = 0.01
# Thus, we have L = 733032 and U = 740398
# Starting WI with k = 33 and deviation = 0.1
# Thus, we have L = 169668 and U = 187527
# Starting WI with k = 99 and deviation = 0.1
# Thus, we have L = 56556 and U = 62509
# Starting WV with k = 2 and deviation = 0.01
# Thus, we have L = 892374 and U = 901342
# Starting WV with k = 17 and deviation = 0.1
# Thus, we have L = 100238 and U = 110788
# Starting WV with k = 100 and deviation = 0.1
# Thus, we have L = 17041 and U = 18834
# Starting WY with k = 1 and deviation = 0.01
# Thus, we have L = 573967 and U = 579735
# Skipping WY CD because k = 1.
# Starting WY with k = 31 and deviation = 0.1
# Thus, we have L = 17678 and U = 19538
# Starting WY with k = 62 and deviation = 0.1
# Thus, we have L = 8839 and U = 9769

# %%
constraints = dict()
for key in results.keys():
    constraints[key] = results[key]['vertex_cut_constraints']
    
print("constraints =",constraints)
# Out:
# constraints = {('AK', 'SS'): [['02020'], ['02090'], ['02122'], ['02170']], ('AK', 'SH'): [['02122'], ['02170'], ['02198', '02195', '02130', '02275'], ['02090'], ['02110'], ['02020']], ('AL', 'CD'): [], ('AL', 'SS'): [['01081'], ['01073'], ['01029', '01121', '01049', '01015', '01009', '01019', '01095', '01115', '01055'], ['01097'], ['01003'], ['01117'], ['01089'], ['01101'], ['01125']], ('AL', 'SH'): [['01121'], ['01127'], ['01115'], ['01055'], ['01009'], ['01089'], ['01049'], ['01033'], ['01073'], ['01031'], ['01069'], ['01097'], ['01083'], ['01117'], ['01077'], ['01081'], ['01071'], ['01095'], ['01003'], ['01015'], ['01103'], ['01113'], ['01001'], ['01051'], ['01043'], ['01101'], ['01125']], ('AR', 'CD'): [], ('AR', 'SS'): [['05125'], ['05045'], ['05131'], ['05143'], ['05119'], ['05051'], ['05007'], ['05031']], ('AR', 'SH'): [['05125'], ['05063'], ['05045'], ['05031'], ['05055'], ['05059'], ['05007'], ['05085'], ['05009'], ['05035'], ['05033'], ['05143'], ['05069'], ['05051'], ['05093'], ['05091'], ['05119'], ['05005'], ['05115'], ['05131'], ['05145'], ['05139']], ('AZ', 'CD'): [['04019'], ['04013']], ('AZ', 'SS'): [['04021'], ['04019'], ['04013']], ('AZ', 'SH'): [['04021'], ['04019'], ['04013']], ('CA', 'CD'): [['06071'], ['06081'], ['06085'], ['06073'], ['06013'], ['06001'], ['06037'], ['06075'], ['06029'], ['06111'], ['06067'], ['06077'], ['06065'], ['06059'], ['06019']], ('CA', 'SS'): [['06071'], ['06085'], ['06073'], ['06013'], ['06001'], ['06037'], ['06029', '06019', '06107', '06053', '06111', '06079', '06083'], ['06067'], ['06065'], ['06059']], ('CA', 'SH'): [['06071'], ['06081'], ['06085'], ['06073'], ['06013'], ['06001'], ['06037'], ['