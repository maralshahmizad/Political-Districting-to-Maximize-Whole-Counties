# %%
from number_of_districts import states as all_states
states = all_states.copy()
states.remove('HI')
print(states)
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
from utils import read_graph_from_json, update_attributes, get_k_L_U
filepath = 'C:\\districting-data-2020-conn\\'
filepath2 = 'min-split-plans\\'
level = 'block'

# %%
from utils import import_from_baf, check_plan
failed_instances = list()

for state in states:
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    for district_type in ['CD', 'SS', 'SH']:

        print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
        (k, L, U) = get_k_L_U(G, state, district_type)
        if k <= 1:
            print("Skipping because k <= 1.")
            continue

        # get warm start plan
        filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
        plan = import_from_baf(G, filepath2, filename)
        
        try:
            check_plan(G, L, U, k, plan)
        except:
            print("Plan is not feasible for some reason!")
            failed_instances.append((state, district_type))
# Out:
# ****************************************
# Starting AK CD
# ****************************************
#
# Starting AK with k = 1 and deviation = 0.01
# Thus, we have L = 729725 and U = 737057
# Skipping because k <= 1.
# ****************************************
# Starting AK SS
# ****************************************
#
# Starting AK with k = 20 and deviation = 0.1
# Thus, we have L = 34837 and U = 38503
# ****************************************
# Starting AK SH
# ****************************************
#
# Starting AK with k = 40 and deviation = 0.1
# Thus, we have L = 17419 and U = 19251
# ****************************************
# Starting AL CD
# ****************************************
#
# Starting AL with k = 7 and deviation = 0.01
# Thus, we have L = 714166 and U = 721342
# ****************************************
# Starting AL SS
# ****************************************
#
# Starting AL with k = 35 and deviation = 0.1
# Thus, we have L = 136374 and U = 150728
# ****************************************
# Starting AL SH
# ****************************************
#
# Starting AL with k = 105 and deviation = 0.1
# Thus, we have L = 45458 and U = 50242
# ****************************************
# Starting AR CD
# ****************************************
#
# Starting AR with k = 4 and deviation = 0.01
# Thus, we have L = 749117 and U = 756645
# ****************************************
# Starting AR SS
# ****************************************
#
# Starting AR with k = 35 and deviation = 0.1
# Thus, we have L = 81742 and U = 90345
# ****************************************
# Starting AR SH
# ****************************************
#
# Starting AR with k = 100 and deviation = 0.1
# Thus, we have L = 28610 and U = 31621
# ****************************************
# Starting AZ CD
# ****************************************
#
# Starting AZ with k = 9 and deviation = 0.01
# Thus, we have L = 790639 and U = 798584
# ****************************************
# Starting AZ SS
# ****************************************
#
# Starting AZ with k = 30 and deviation = 0.1
# Thus, we have L = 226465 and U = 250302
# ****************************************
# Starting AZ SH
# ****************************************
#
# Starting AZ with k = 30 and deviation = 0.1
# Thus, we have L = 226465 and U = 250302
# ****************************************
# Starting CA CD
# ****************************************
#
# Starting CA with k = 52 and deviation = 0.01
# Thus, we have L = 756549 and U = 764152
# Plan is not feasible for some reason!
# ****************************************
# Starting CA SS
# ****************************************
#
# Starting CA with k = 40 and deviation = 0.1
# Thus, we have L = 939033 and U = 1037878
# Plan is not feasible for some reason!
# ****************************************
# Starting CA SH
# ****************************************
#
# Starting CA with k = 80 and deviation = 0.1
# Thus, we have L = 469517 and U = 518939
# Plan is not feasible for some reason!
# ****************************************
# Starting CO CD
# ****************************************
#
# Starting CO with k = 8 and deviation = 0.01
# Thus, we have L = 718106 and U = 725322
# ****************************************
# Starting CO SS
# ****************************************
#
# Starting CO with k = 35 and deviation = 0.1
# Thus, we have L = 156716 and U = 173211
# ****************************************
# Starting CO SH
# ****************************************
#
# Starting CO with k = 65 and deviation = 0.1
# Thus, we have L = 84386 and U = 93267
# ****************************************
# Starting CT CD
# ****************************************
#
# Starting CT with k = 5 and deviation = 0.01
# Thus, we have L = 717583 and U = 724794
# ****************************************
# Starting CT SS
# ****************************************
#
# Starting CT with k = 36 and deviation = 0.1
# Thus, we have L = 95157 and U = 105173
# ****************************************
# Starting CT SH
# ****************************************
#
# Starting CT with k = 151 and deviation = 0.1
# Thus, we have L = 22687 and U = 25074
# ****************************************
# Starting DE CD
# ****************************************
#
# Starting DE with k = 1 and deviation = 0.01
# Thus, we have L = 984999 and U = 994897
# Skipping because k <= 1.
# ****************************************
# Starting DE SS
# ****************************************
#
# Starting DE with k = 21 and deviation = 0.1
# Thus, we have L = 44784 and U = 49497
# Plan is not feasible for some reason!
# ****************************************
# Starting DE SH
# ****************************************
#
# Starting DE with k = 41 and deviation = 0.1
# Thus, we have L = 22938 and U = 25352
# Plan is not feasible for some reason!
# ****************************************
# Starting FL CD
# ****************************************
#
# Starting FL with k = 28 and deviation = 0.01
# Thus, we have L = 765375 and U = 773067
# ****************************************
# Starting FL SS
# ****************************************
#
# Starting FL with k = 40 and deviation = 0.1
# Thus, we have L = 511532 and U = 565377
# ****************************************
# Starting FL SH
# ****************************************
#
# Starting FL with k = 120 and deviation = 0.1
# Thus, we have L = 170511 and U = 188459
# ****************************************
# Starting GA CD
# ****************************************
#
# Starting GA with k = 14 and deviation = 0.01
# Thus, we have L = 761311 and U = 768961
# ****************************************
# Starting GA SS
# ****************************************
#
# Starting GA with k = 56 and deviation = 0.1
# Thus, we have L = 181720 and U = 200848
# ****************************************
# Starting GA SH
# ****************************************
#
# Starting GA with k = 180 and deviation = 0.1
# Thus, we have L = 56536 and U = 62486
# ****************************************
# Starting IA CD
# ****************************************
#
# Starting IA with k = 4 and deviation = 0.01
# Thus, we have L = 793605 and U = 801580
# ****************************************
# Starting IA SS
# ****************************************
#
# Starting IA with k = 50 and deviation = 0.1
# Thus, we have L = 60618 and U = 66997
# ****************************************
# Starting IA SH
# ****************************************
#
# Starting IA with k = 100 and deviation = 0.1
# Thus, we have L = 30309 and U = 33498
# ****************************************
# Starting ID CD
# ****************************************
#
# Starting ID with k = 2 and deviation = 0.01
# Thus, we have L = 914956 and U = 924150
# ****************************************
# Starting ID SS
# ****************************************
#
# Starting ID with k = 35 and deviation = 0.1
# Thus, we have L = 49919 and U = 55173
# ****************************************
# Starting ID SH
# ****************************************
#
# Starting ID with k = 35 and deviation = 0.1
# Thus, we have L = 49919 and U = 55173
# ****************************************
# Starting IL CD
# ****************************************
#
# Starting IL with k = 17 and deviation = 0.01
# Thus, we have L = 749909 and U = 757445
# ****************************************
# Starting IL SS
# ****************************************
#
# Starting IL with k = 59 and deviation = 0.1
# Thus, we have L = 206304 and U = 228019
# ****************************************
# Starting IL SH
# ****************************************
#
# Starting IL with k = 118 and deviation = 0.1
# Thus, we have L = 103152 and U = 114009
# Plan is not feasible for some reason!
# ****************************************
# Starting IN CD
# ****************************************
#
# Starting IN with k = 9 and deviation = 0.01
# Thus, we have L = 750178 and U = 757717
# ****************************************
# Starting IN SS
# ****************************************
#
# Starting IN with k = 50 and deviation = 0.1
# Thus, we have L = 128926 and U = 142496
# ****************************************
# Starting IN SH
# ****************************************
#
# Starting IN with k = 100 and deviation = 0.1
# Thus, we have L = 64463 and U = 71248
# ****************************************
# Starting KS CD
# ****************************************
#
# Starting KS with k = 4 and deviation = 0.01
# Thus, we have L = 730798 and U = 738142
# ****************************************
# Starting KS SS
# ****************************************
#
# Starting KS with k = 40 and deviation = 0.1
# Thus, we have L = 69775 and U = 77119
# ****************************************
# Starting KS SH
# ****************************************
#
# Starting KS with k = 125 and deviation = 0.1
# Thus, we have L = 22328 and U = 24678
# ****************************************
# Starting KY CD
# ****************************************
#
# Starting KY with k = 6 and deviation = 0.01
# Thus, we have L = 747218 and U = 754727
# ****************************************
# Starting KY SS
# ****************************************
#
# Starting KY with k = 38 and deviation = 0.1
# Thus, we have L = 112646 and U = 124503
# ****************************************
# Starting KY SH
# ****************************************
#
# Starting KY with k = 100 and deviation = 0.1
# Thus, we have L = 42806 and U = 47311
# ****************************************
# Starting LA CD
# ****************************************
#
# Starting LA with k = 6 and deviation = 0.01
# Thus, we have L = 772412 and U = 780174
# ****************************************
# Starting LA SS
# ****************************************
#
# Starting LA with k = 39 and deviation = 0.1
# Thus, we have L = 113459 and U = 125401
# ****************************************
# Starting LA SH
# ****************************************
#
# Starting LA with k = 105 and deviation = 0.1
# Thus, we have L = 42142 and U = 46577
# ****************************************
# Starting MA CD
# ****************************************
#
# Starting MA with k = 9 and deviation = 0.01
# Thus, we have L = 777197 and U = 785007
# ****************************************
# Starting MA SS
# ****************************************
#
# Starting MA with k = 40 and deviation = 0.1
# Thus, we have L = 166961 and U = 184535
# Plan is not feasible for some reason!
# ****************************************
# Starting MA SH
# ****************************************
#
# Starting MA with k = 160 and deviation = 0.1
# Thus, we have L = 41741 and U = 46133
# Plan is not feasible for some reason!
# ****************************************
# Starting MD CD
# ****************************************
#
# Starting MD with k = 8 and deviation = 0.01
# Thus, we have L = 768293 and U = 776013
# ****************************************
# Starting MD SS
# ****************************************
#
# Starting MD with k = 47 and deviation = 0.1
# Thus, we have L = 124859 and U = 138001
# ****************************************
# Starting MD SH
# ****************************************
#
# Starting MD with k = 47 and deviation = 0.1
# Thus, we have L = 124859 and U = 138001
# ****************************************
# Starting ME CD
# ****************************************
#
# Starting ME with k = 2 and deviation = 0.01
# Thus, we have L = 677774 and U = 684585
# ****************************************
# Starting ME SS
# ****************************************
#
# Starting ME with k = 35 and deviation = 0.1
# Thus, we have L = 36979 and U = 40870
# Plan is not feasible for some reason!
# ****************************************
# Starting ME SH
# ****************************************
#
# Starting ME with k = 151 and deviation = 0.1
# Thus, we have L = 8572 and U = 9473
# ****************************************
# Starting MI CD
# ****************************************
#
# Starting MI with k = 13 and deviation = 0.01
# Thus, we have L = 771304 and U = 779055
# ****************************************
# Starting MI SS
# ****************************************
#
# Starting MI with k = 38 and deviation = 0.1
# Thus, we have L = 251934 and U = 278452
# ****************************************
# Starting MI SH
# ****************************************
#
# Starting MI with k = 110 and deviation = 0.1
# Thus, we have L = 87032 and U = 96192
# ****************************************
# Starting MN CD
# ****************************************
#
# Starting MN with k = 8 and deviation = 0.01
# Thus, we have L = 709746 and U = 716878
# ****************************************
# Starting MN SS
# ****************************************
#
# Starting MN with k = 67 and deviation = 0.1
# Thus, we have L = 80913 and U = 89430
# ****************************************
# Starting MN SH
# ****************************************
#
# Starting MN with k = 134 and deviation = 0.1
# Thus, we have L = 40457 and U = 44715
# ****************************************
# Starting MO CD
# ****************************************
#
# Starting MO with k = 8 and deviation = 0.01
# Thus, we have L = 765518 and U = 773210
# ****************************************
# Starting MO SS
# ****************************************
#
# Starting MO with k = 34 and deviation = 0.1
# Thus, we have L = 171976 and U = 190078
# ****************************************
# Starting MO SH
# ****************************************
#
# Starting MO with k = 163 and deviation = 0.1
# Thus, we have L = 35873 and U = 39648
# ****************************************
# Starting MS CD
# ****************************************
#
# Starting MS with k = 4 and deviation = 0.01
# Thus, we have L = 736619 and U = 744021
# ****************************************
# Starting MS SS
# ****************************************
#
# Starting MS with k = 52 and deviation = 0.1
# Thus, we have L = 54101 and U = 59795
# Plan is not feasible for some reason!
# ****************************************
# Starting MS SH
# ****************************************
#
# Starting MS with k = 122 and deviation = 0.1
# Thus, we have L = 23060 and U = 25486
# Plan is not feasible for some reason!
# ****************************************
# Starting MT CD
# ****************************************
#
# Starting MT with k = 2 and deviation = 0.01
# Thus, we have L = 539402 and U = 544823
# ****************************************
# Starting MT SS
# ****************************************
#
# Starting MT with k = 50 and deviation = 0.1
# Thus, we have L = 20601 and U = 22768
# ****************************************
# Starting MT SH
# ****************************************
#
# Starting MT with k = 100 and deviation = 0.1
# Thus, we have L = 10301 and U = 11384
# ****************************************
# Starting NC CD
# ****************************************
#
# Starting NC with k = 14 and deviation = 0.01
# Thus, we have L = 741943 and U = 749398
# ****************************************
# Starting NC SS
# ****************************************
#
# Starting NC with k = 50 and deviation = 0.1
# Thus, we have L = 198349 and U = 219227
# ****************************************
# Starting NC SH
# ****************************************
#
# Starting NC with k = 120 and deviation = 0.1
# Thus, we have L = 82646 and U = 91344
# ****************************************
# Starting ND CD
# ****************************************
#
# Starting ND with k = 1 and deviation = 0.01
# Thus, we have L = 775199 and U = 782989
# Skipping because k <= 1.
# ****************************************
# Starting ND SS
# ****************************************
#
# Starting ND with k = 47 and deviation = 0.1
# Thus, we have L = 15748 and U = 17405
# ****************************************
# Starting ND SH
# ****************************************
#
# Starting ND with k = 47 and deviation = 0.1
# Thus, we have L = 15748 and U = 17405
# ****************************************
# Starting NE CD
# ****************************************
#
# Starting NE with k = 3 and deviation = 0.01
# Thus, we have L = 650566 and U = 657103
# ****************************************
# Starting NE SS
# ****************************************
#
# Starting NE with k = 49 and deviation = 0.1
# Thus, we have L = 38030 and U = 42032
# ****************************************
# Starting NE SH
# ****************************************
#
# Starting NE with k = 0 and deviation = 0.1
# Thus, we have L = 0 and U = 0
# Skipping because k <= 1.
# ****************************************
# Starting NH CD
# ****************************************
#
# Starting NH with k = 2 and deviation = 0.01
# Thus, we have L = 685321 and U = 692208
# ****************************************
# Starting NH SS
# ****************************************
#
# Starting NH with k = 24 and deviation = 0.1
# Thus, we have L = 54528 and U = 60266
# ****************************************
# Starting NH SH
# ****************************************
#
# Starting NH with k = 400 and deviation = 0.1
# Thus, we have L = 3272 and U = 3616
# ****************************************
# Starting NJ CD
# ****************************************
#
# Starting NJ with k = 12 and deviation = 0.01
# Thus, we have L = 770213 and U = 777953
# ****************************************
# Starting NJ SS
# ****************************************
#
# Starting NJ with k = 40 and deviation = 0.1
# Thus, we have L = 220614 and U = 243836
# ****************************************
# Starting NJ SH
# ****************************************
#
# Starting NJ with k = 40 and deviation = 0.1
# Thus, we have L = 220614 and U = 243836
# ****************************************
# Starting NM CD
# ****************************************
#
# Starting NM with k = 3 and deviation = 0.01
# Thus, we have L = 702312 and U = 709369
# ****************************************
# Starting NM SS
# ****************************************
#
# Starting NM with k = 42 and deviation = 0.1
# Thus, we have L = 47897 and U = 52938
# ****************************************
# Starting NM SH
# ****************************************
#
# Starting NM with k = 70 and deviation = 0.1
# Thus, we have L = 28738 and U = 31762
# ****************************************
# Starting NV CD
# ****************************************
#
# Starting NV with k = 4 and deviation = 0.01
# Thus, we have L = 772273 and U = 780034
# ****************************************
# Starting NV SS
# ****************************************
#
# Starting NV with k = 21 and deviation = 0.1
# Thus, we have L = 140447 and U = 155230
# ****************************************
# Starting NV SH
# ****************************************
#
# Starting NV with k = 42 and deviation = 0.1
# Thus, we have L = 70224 and U = 77615
# ****************************************
# Starting NY CD
# ****************************************
#
# Starting NY with k = 26 and deviation = 0.01
# Thus, we have L = 773087 and U = 780855
# ****************************************
# Starting NY SS
# ****************************************
#
# Starting NY with k = 63 and deviation = 0.1
# Thus, we have L = 304623 and U = 336687
# ****************************************
# Starting NY SH
# ****************************************
#
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# Plan is not feasible for some reason!
# ****************************************
# Starting OH CD
# ****************************************
#
# Starting OH with k = 15 and deviation = 0.01
# Thus, we have L = 782697 and U = 790563
# ****************************************
# Starting OH SS
# ****************************************
#
# Starting OH with k = 33 and deviation = 0.1
# Thus, we have L = 339682 and U = 375436
# ****************************************
# Starting OH SH
# ****************************************
#
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# Plan is not feasible for some reason!
# ****************************************
# Starting OK CD
# ****************************************
#
# Starting OK with k = 5 and deviation = 0.01
# Thus, we have L = 787912 and U = 795829
# ****************************************
# Starting OK SS
# ****************************************
#
# Starting OK with k = 48 and deviation = 0.1
# Thus, we have L = 78363 and U = 86610
# ****************************************
# Starting OK SH
# ****************************************
#
# Starting OK with k = 101 and deviation = 0.1
# Thus, we have L = 37242 and U = 41161
# ****************************************
# Starting OR CD
# ****************************************
#
# Starting OR with k = 6 and deviation = 0.01
# Thus, we have L = 702679 and U = 709740
# ****************************************
# Starting OR SS
# ****************************************
#
# Starting OR with k = 30 and deviation = 0.1
# Thus, we have L = 134180 and U = 148303
# ****************************************
# Starting OR SH
# ****************************************
#
# Starting OR with k = 60 and deviation = 0.1
# Thus, we have L = 67090 and U = 74151
# ****************************************
# Starting PA CD
# ****************************************
#
# Starting PA with k = 17 and deviation = 0.01
# Thus, we have L = 761041 and U = 768689
# ****************************************
# Starting PA SS
# ****************************************
#
# Starting PA with k = 50 and deviation = 0.1
# Thus, we have L = 247052 and U = 273056
# ****************************************
# Starting PA SH
# ****************************************
#
# Starting PA with k = 203 and deviation = 0.1
# Thus, we have L = 60851 and U = 67255
# ****************************************
# Starting RI CD
# ****************************************
#
# Starting RI with k = 2 and deviation = 0.01
# Thus, we have L = 545947 and U = 551432
# ****************************************
# Starting RI SS
# ****************************************
#
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# Plan is not feasible for some reason!
# ****************************************
# Starting RI SH
# ****************************************
#
# Starting RI with k = 75 and deviation = 0.1
# Thus, we have L = 13901 and U = 15363
# ****************************************
# Starting SC CD
# ****************************************
#
# Starting SC with k = 7 and deviation = 0.01
# Thus, we have L = 727548 and U = 734859
# ****************************************
# Starting SC SS
# ****************************************
#
# Starting SC with k = 46 and deviation = 0.1
# Thus, we have L = 105707 and U = 116833
# ****************************************
# Starting SC SH
# ****************************************
#
# Starting SC with k = 124 and deviation = 0.1
# Thus, we have L = 39214 and U = 43341
# ****************************************
# Starting SD CD
# ****************************************
#
# Starting SD with k = 1 and deviation = 0.01
# Thus, we have L = 882234 and U = 891100
# Skipping because k <= 1.
# ****************************************
# Starting SD SS
# ****************************************
#
# Starting SD with k = 35 and deviation = 0.1
# Thus, we have L = 24067 and U = 26600
# ****************************************
# Starting SD SH
# ****************************************
#
# Starting SD with k = 35 and deviation = 0.1
# Thus, we have L = 24067 and U = 26600
# ****************************************
# Starting TN CD
# ****************************************
#
# Starting TN with k = 9 and deviation = 0.01
# Thus, we have L = 764032 and U = 771710
# ****************************************
# Starting TN SS
# ****************************************
#
# Starting TN with k = 33 and deviation = 0.1
# Thus, we have L = 198949 and U = 219890
# ****************************************
# Starting TN SH
# ****************************************
#
# Starting TN with k = 99 and deviation = 0.1
# Thus, we have L = 66317 and U = 73296
# ****************************************
# Starting TX CD
# ****************************************
#
# Starting TX with k = 38 and deviation = 0.01
# Thus, we have L = 763153 and U = 770821
# ****************************************
# Starting TX SS
# ****************************************
#
# Starting TX with k = 31 and deviation = 0.1
# Thus, we have L = 893169 and U = 987186
# ****************************************
# Starting TX SH
# ****************************************
#
# Starting TX with k = 150 and deviation = 0.1
# Thus, we have L = 184589 and U = 204018
# ****************************************
# Starting UT CD
# ****************************************
#
# Starting UT with k = 4 and deviation = 0.01
# Thus, we have L = 813815 and U = 821993
# ****************************************
# Starting UT SS
# ****************************************
#
# Starting UT with k = 29 and deviation = 0.1
# Thus, we have L = 107174 and U = 118455
# ****************************************
# Starting UT SH
# ****************************************
#
# Starting UT with k = 75 and deviation = 0.1
# Thus, we have L = 41441 and U = 45802
# ****************************************
# Starting VA CD
# ****************************************
#
# Starting VA with k = 11 and deviation = 0.01
# Thus, we have L = 780749 and U = 788595
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# Plan is not feasible for some reason!
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# Plan is not feasible for some reason!
# ****************************************
# Starting VT CD
# ****************************************
#
# Starting VT with k = 1 and deviation = 0.01
# Thus, we have L = 639862 and U = 646292
# Skipping because k <= 1.
# ****************************************
# Starting VT SS
# ****************************************
#
# Starting VT with k = 30 and deviation = 0.1
# Thus, we have L = 20365 and U = 22507
# ****************************************
# Starting VT SH
# ****************************************
#
# Starting VT with k = 150 and deviation = 0.1
# Thus, we have L = 4073 and U = 4501
# ****************************************
# Starting WA CD
# ****************************************
#
# Starting WA with k = 10 and deviation = 0.01
# Thus, we have L = 766676 and U = 774380
# ****************************************
# Starting WA SS
# ****************************************
#
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# Plan is not feasible for some reason!
# ****************************************
# Starting WA SH
# ****************************************
#
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# Plan is not feasible for some reason!
# ****************************************
# Starting WI CD
# ****************************************
#
# Starting WI with k = 8 and deviation = 0.01
# Thus, we have L = 733032 and U = 740398
# ****************************************
# Starting WI SS
# ****************************************
#
# Starting WI with k = 33 and deviation = 0.1
# Thus, we have L = 169668 and U = 187527
# ****************************************
# Starting WI SH
# ****************************************
#
# Starting WI with k = 99 and deviation = 0.1
# Thus, we have L = 56556 and U = 62509
# ****************************************
# Starting WV CD
# ****************************************
#
# Starting WV with k = 2 and deviation = 0.01
# Thus, we have L = 892374 and U = 901342
# ****************************************
# Starting WV SS
# ****************************************
#
# Starting WV with k = 17 and deviation = 0.1
# Thus, we have L = 100238 and U = 110788
# ****************************************
# Starting WV SH
# ****************************************
#
# Starting WV with k = 100 and deviation = 0.1
# Thus, we have L = 17041 and U = 18834
# ****************************************
# Starting WY CD
# ****************************************
#
# Starting WY with k = 1 and deviation = 0.01
# Thus, we have L = 573967 and U = 579735
# Skipping because k <= 1.
# ****************************************
# Starting WY SS
# ****************************************
#
# Starting WY with k = 31 and deviation = 0.1
# Thus, we have L = 17678 and U = 19538
# Plan is not feasible for some reason!
# ****************************************
# Starting WY SH
# ****************************************
#
# Starting WY with k = 62 and deviation = 0.1
# Thus, we have L = 8839 and U = 9769

# %%
for inst in failed_instances:
    print(inst)
# Out:
# ('CA', 'CD')
# ('CA', 'SS')
# ('CA', 'SH')
# ('DE', 'SS')
# ('DE', 'SH')
# ('IL', 'SH')
# ('MA', 'SS')
# ('MA', 'SH')
# ('ME', 'SS')
# ('MS', 'SS')
# ('MS', 'SH')
# ('NY', 'SH')
# ('OH', 'SH')
# ('RI', 'SS')
# ('VA', 'SS')
# ('VA', 'SH')
# ('WA', 'SS')
# ('WA', 'SH')
# ('WY', 'SS')

# %%
import networkx as nx

for (state, district_type) in failed_instances:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for district in plan:
        if not nx.is_connected( G.subgraph(district) ):
            print([len(comp) for comp in nx.connected_components(G.subgraph(district))])
    #print("populations:",sorted([sum( G.nodes[i]['TOTPOP'] for i in district ) for district in plan ]) )
# Out:
# ****************************************
# Starting CA CD
# ****************************************
#
# Starting CA with k = 52 and deviation = 0.01
# Thus, we have L = 756549 and U = 764152
# [8917, 1]
# [14903, 1]
# populations: [756550, 756556, 756559, 756561, 756565, 756583, 756657, 756681, 756761, 756887, 757207, 757274, 757369, 757568, 757734, 757946, 757963, 758035, 758152, 758368, 758637, 758901, 759165, 759896, 759994, 760126, 760665, 760773, 760868, 760955, 761101, 762116, 762161, 762209, 762571, 762612, 762718, 763024, 763544, 763739, 763770, 763845, 763970, 764001, 764045, 764074, 764087, 764111, 764124, 764142, 764151, 764152]
# ****************************************
# Starting CA SS
# ****************************************
#
# Starting CA with k = 40 and deviation = 0.1
# Thus, we have L = 939033 and U = 1037878
# [11315, 1]
# populations: [939119, 939151, 939195, 939292, 939446, 939450, 939471, 940238, 941371, 941586, 941667, 942171, 945529, 946677, 947776, 950559, 957366, 961752, 992070, 992630, 994888, 1001576, 1002393, 1008654, 1013452, 1027574, 1033960, 1035303, 1035810, 1036040, 1036349, 1036567, 1036908, 1036970, 1037412, 1037423, 1037499, 1037511, 1037625, 1037793]
# ****************************************
# Starting CA SH
# ****************************************
#
# Starting CA with k = 80 and deviation = 0.1
# Thus, we have L = 469517 and U = 518939
# [10722, 7]
# [5678, 4]
# [4131, 1]
# [5277, 1]
# populations: [469577, 469852, 469893, 469928, 469949, 470082, 470177, 470191, 470265, 470291, 470381, 470444, 470490, 470510, 470983, 471346, 471375, 471458, 471510, 471778, 471794, 471799, 471928, 472113, 472125, 472129, 472338, 472593, 473117, 473140, 473341, 476609, 479940, 480704, 483053, 483065, 485266, 485626, 487539, 488395, 488863, 490164, 503244, 504372, 506850, 507873, 510208, 511614, 512939, 513612, 515768, 516050, 516299, 516303, 516458, 516526, 516888, 517033, 517082, 517543, 517558, 517707, 517725, 517775, 517782, 517841, 517883, 517931, 518150, 518160, 518295, 518490, 518638, 518680, 518710, 518735, 518777, 518821, 518867, 518915]
# ****************************************
# Starting DE SS
# ****************************************
#
# Starting DE with k = 21 and deviation = 0.1
# Thus, we have L = 44784 and U = 49497
# [612, 1]
# populations: [44831, 44905, 44964, 45102, 45361, 45540, 45837, 46424, 46879, 46884, 47287, 47651, 48112, 48140, 48463, 48506, 48668, 48838, 48889, 49242, 49425]
# ****************************************
# Starting DE SH
# ****************************************
#
# Starting DE with k = 41 and deviation = 0.1
# Thus, we have L = 22938 and U = 25352
# [455, 1]
# [449, 1]
# populations: [23048, 23067, 23082, 23115, 23200, 23238, 23280, 23361, 23368, 23379, 23537, 23580, 23603, 23648, 23987, 24025, 24055, 24113, 24240, 24247, 24248, 24284, 24310, 24337, 24356, 24371, 24396, 24419, 24527, 24582, 24714, 24758, 24790, 24795, 24839, 25050, 25113, 25153, 25219, 25233, 25281]
# ****************************************
# Starting IL SH
# ****************************************
#
# Starting IL with k = 118 and deviation = 0.1
# Thus, we have L = 103152 and U = 114009
# [4391, 1]
# populations: [103153, 103190, 103229, 103232, 103233, 103253, 103261, 103279, 103284, 103302, 103354, 103368, 103382, 103423, 103457, 103464, 103498, 103519, 103532, 103535, 103771, 103807, 103839, 103855, 103886, 103923, 103930, 103998, 104088, 104105, 104185, 104250, 104324, 104336, 104378, 104390, 104483, 104664, 104742, 104765, 105114, 105424, 105446, 105497, 105538, 105561, 105809, 106129, 106198, 106617, 106721, 107386, 107436, 107502, 107502, 107726, 108128, 108177, 108270, 108558, 108745, 109591, 109658, 109689, 109841, 110327, 110495, 110696, 110697, 110794, 111051, 111123, 111235, 111303, 111332, 111469, 111881, 111930, 111959, 112303, 112394, 112398, 112764, 112794, 112826, 112947, 112975, 113055, 113081, 113125, 113267, 113326, 113356, 113360, 113372, 113418, 113423, 113429, 113542, 113542, 113592, 113606, 113685, 113685, 113688, 113727, 113747, 113750, 113756, 113817, 113867, 113911, 113926, 113928, 113938, 113973, 113985, 114008]
# ****************************************
# Starting MA SS
# ****************************************
#
# Starting MA with k = 40 and deviation = 0.1
# Thus, we have L = 166961 and U = 184535
# [2606, 3]
# populations: [167004, 167043, 167131, 167371, 167603, 167679, 167851, 167950, 168045, 168076, 168284, 168511, 168756, 168845, 169460, 169552, 170677, 171769, 172112, 175869, 178317, 178660, 180649, 180885, 181482, 181512, 181625, 182166, 182281, 182442, 182726, 183718, 183933, 184104, 184113, 184189, 184304, 184358, 184373, 184492]
# ****************************************
# Starting MA SH
# ****************************************
#
# Starting MA with k = 160 and deviation = 0.1
# Thus, we have L = 41741 and U = 46133
# [716, 3, 2]
# populations: [41741, 41742, 41743, 41743, 41744, 41744, 41747, 41748, 41748, 41750, 41755, 41769, 41771, 41777, 41779, 41782, 41800, 41831, 41845, 41859, 41899, 41920, 41936, 41938, 41943, 41963, 41982, 42001, 42002, 42052, 42054, 42080, 42109, 42116, 42150, 42177, 42259, 42277, 42285, 42309, 42341, 42358, 42380, 42400, 42437, 42560, 42589, 42668, 42751, 42756, 42777, 42834, 42857, 42896, 42979, 42987, 43011, 43035, 43044, 43073, 43143, 43146, 43161, 43171, 43290, 43444, 43478, 43517, 43575, 43588, 43662, 43676, 43706, 43730, 43762, 43763, 43782, 43843, 43883, 43942, 44043, 44050, 44069, 44088, 44114, 44257, 44293, 44318, 44370, 44396, 44464, 44546, 44548, 44551, 44657, 44688, 44689, 44708, 44719, 44755, 44771, 44793, 44793, 44872, 44994, 45031, 45080, 45087, 45171, 45212, 45222, 45248, 45251, 45261, 45277, 45313, 45419, 45425, 45447, 45451, 45457, 45483, 45557, 45600, 45643, 45646, 45691, 45699, 45772, 45776, 45809, 45812, 45839, 45863, 45864, 45880, 45894, 45924, 45926, 45937, 45948, 45953, 45957, 45957, 45970, 45971, 45974, 45991, 46023, 46028, 46029, 46048, 46054, 46058, 46063, 46076, 46080, 46108, 46123, 46128]
# ****************************************
# Starting ME SS
# ****************************************
#
# Starting ME with k = 35 and deviation = 0.1
# Thus, we have L = 36979 and U = 40870
# [1596, 3]
# populations: [36989, 37013, 37015, 37053, 37091, 37137, 37165, 37514, 37633, 37858, 37977, 38133, 38429, 38431, 38442, 38448, 38726, 38863, 39067, 39255, 39607, 39723, 39764, 39765, 39855, 40285, 40291, 40424, 40449, 40583, 40607, 40647, 40656, 40678, 40786]
# ****************************************
# Starting MS SS
# ****************************************
#
# Starting MS with k = 52 and deviation = 0.1
# Thus, we have L = 54101 and U = 59795
# [1306, 11, 14]
# [1950, 9, 24]
# populations: [54112, 54183, 54196, 54208, 54233, 54317, 54333, 54387, 54758, 54900, 55121, 55195, 55391, 55694, 55703, 55712, 55789, 55813, 56145, 56164, 56305, 56377, 56388, 56446, 56507, 56892, 56932, 56956, 57046, 57228, 57238, 57635, 57659, 57698, 58038, 58363, 58520, 58566, 58879, 58955, 59104, 59116, 59118, 59133, 59191, 59236, 59384, 59411, 59523, 59647, 59686, 59748]
# ****************************************
# Starting MS SH
# ****************************************
#
# Starting MS with k = 122 and deviation = 0.1
# Thus, we have L = 23060 and U = 25486
# [938, 24, 9]
# populations: [23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23060, 23061, 23061, 23061, 23062, 23063, 23068, 23073, 23079, 23080, 23089, 23098, 23102, 23121, 23147, 23180, 23188, 23192, 23204, 23214, 23253, 23372, 23553, 23572, 23602, 23613, 23617, 23682, 23768, 23785, 23821, 23832, 23863, 23871, 23884, 23900, 23985, 24039, 24070, 24299, 24300, 24301, 24301, 24306, 24350, 24357, 24423, 24434, 24441, 24464, 24531, 24561, 24563, 24567, 24704, 24718, 24770, 24785, 24812, 24860, 24891, 24936, 24938, 24956, 24965, 24989, 24994, 25008, 25041, 25053, 25053, 25192, 25196, 25220, 25230, 25249, 25273, 25297, 25298, 25304, 25354, 25359, 25408, 25442, 25448, 25456, 25466, 25469, 25470, 25474, 25474, 25485, 25485, 25485, 25485, 25485, 25485, 25486, 25486, 25486, 25486, 25486, 25486, 25486, 25486, 25486]
# ****************************************
# Starting NY SH
# ****************************************
#
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# [5130, 2, 3, 2, 7, 2, 2, 2]
# populations: [127942, 127964, 127965, 127968, 127972, 127975, 128004, 128004, 128008, 128016, 128020, 128047, 128120, 128133, 128154, 128156, 128191, 128226, 128230, 128231, 128234, 128258, 128278, 128312, 128336, 128347, 128372, 128384, 128400, 128402, 128457, 128483, 128551, 128557, 128569, 128580, 128651, 128754, 128761, 128851, 128860, 128928, 128994, 129121, 129296, 129791, 129813, 129973, 129993, 130034, 130044, 130100, 130154, 130345, 130391, 130401, 130536, 130679, 131127, 131154, 131273, 131439, 131445, 131571, 131690, 131968, 131992, 132135, 132146, 132336, 132603, 132942, 132943, 133124, 133678, 134357, 134500, 135083, 135151, 135961, 136256, 136454, 137026, 137224, 138026, 138079, 138764, 138780, 138862, 138953, 139039, 139051, 139085, 139110, 139324, 139340, 139472, 139554, 139606, 139666, 139747, 139818, 139831, 139861, 140009, 140014, 140101, 140140, 140153, 140219, 140286, 140365, 140423, 140485, 140493, 140509, 140613, 140657, 140664, 140667, 140869, 140886, 140900, 140959, 140975, 141015, 141041, 141059, 141073, 141073, 141098, 141128, 141154, 141160, 141211, 141226, 141246, 141262, 141304, 141306, 141308, 141315, 141317, 141361, 141379, 141379, 141381, 141395, 141403, 141406]
# ****************************************
# Starting OH SH
# ****************************************
#
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# [2711, 55]
# populations: [113277, 113452, 113514, 113515, 113594, 113645, 113664, 113672, 113687, 113700, 113910, 113965, 113984, 114042, 114049, 114270, 114397, 114470, 114624, 114703, 114752, 114793, 114867, 114950, 115000, 115084, 115086, 115168, 115170, 115216, 115233, 115360, 115370, 115481, 115537, 115721, 115792, 115855, 115986, 116096, 116602, 116870, 116894, 116933, 117387, 117595, 117964, 118101, 118486, 118665, 119273, 119583, 119686, 119834, 119984, 120578, 120923, 121562, 121722, 121820, 122193, 122202, 122272, 122306, 122309, 122337, 122416, 122505, 122955, 123100, 123244, 123372, 123568, 123591, 124165, 124176, 124245, 124273, 124290, 124363, 124397, 124431, 124515, 124594, 124606, 124614, 124626, 124702, 124716, 124742, 124789, 124801, 124829, 124936, 124962, 125004, 125061, 125062, 125066]
# ****************************************
# Starting RI SS
# ****************************************
#
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# [342, 58, 1, 223]
# [437, 390]
# [826, 1]
# populations: [27530, 27592, 27703, 27780, 27818, 27841, 27869, 28035, 28078, 28134, 28141, 28182, 28209, 28535, 28582, 28607, 28810, 28836, 29004, 29032, 29059, 29068, 29069, 29094, 29215, 29351, 29429, 29477, 29511, 29666, 29703, 29770, 29796, 29937, 30169, 30175, 30265, 30307]
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# [2395, 6, 6]
# populations: [205000, 205008, 205147, 205363, 205549, 205696, 205867, 206106, 206329, 207072, 207822, 208354, 208366, 208827, 209040, 212696, 214146, 214167, 214567, 214716, 214980, 215959, 218415, 219140, 220419, 220566, 221649, 222001, 222286, 224853, 224855, 224975, 226132, 226249, 226408, 226463, 226527, 226556, 226558, 226564]
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# [1140, 6, 6]
# [699, 5]
# [798, 5]
# populations: [82005, 82036, 82041, 82111, 82155, 82232, 82273, 82287, 82309, 82363, 82374, 82510, 82548, 82639, 82640, 82656, 82680, 82760, 82820, 82914, 82918, 82938, 82942, 83063, 83082, 83146, 83297, 83433, 83476, 83486, 83544, 83566, 83596, 83647, 83762, 84124, 84259, 84313, 84453, 84470, 84522, 84784, 84799, 85027, 85040, 85157, 85470, 85581, 85691, 85721, 85745, 85753, 85912, 86078, 86487, 87313, 87480, 87581, 87725, 87895, 88000, 88264, 88272, 88368, 88555, 88593, 88715, 88806, 88941, 89080, 89296, 89360, 89628, 89718, 89822, 89848, 89978, 89985, 90007, 90074, 90075, 90099, 90142, 90271, 90308, 90312, 90333, 90348, 90419, 90510, 90515, 90533, 90540, 90543, 90554, 90559, 90573, 90588, 90609, 90623]
# ****************************************
# Starting WA SS
# ****************************************
#
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# [2061, 3]
# [1981, 17]
# populations: [149512, 149514, 149545, 149567, 149684, 149908, 149930, 149956, 150308, 150586, 150685, 150829, 150902, 150936, 151156, 151177, 151321, 151907, 152466, 152770, 153011, 153221, 153306, 154149, 155060, 155577, 156451, 159993, 162884, 163535, 163701, 163729, 163749, 163834, 164073, 164088, 164116, 164480, 164727, 164778, 164811, 164830, 164839, 164861, 164917, 164930, 164932, 164967, 165073]
# ****************************************
# Starting WA SH
# ****************************************
#
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# [2061, 3]
# [1981, 17]
# populations: [149512, 149514, 149545, 149567, 149684, 149908, 149930, 149956, 150308, 150586, 150685, 150829, 150902, 150936, 151156, 151177, 151321, 151907, 152466, 152770, 153011, 153221, 153306, 154149, 155060, 155577, 156451, 159993, 162884, 163535, 163701, 163729, 163749, 163834, 164073, 164088, 164116, 164480, 164727, 164778, 164811, 164830, 164839, 164861, 164917, 164930, 164932, 164967, 165073]
# ****************************************
# Starting WY SS
# ****************************************
#
# Starting WY with k = 31 and deviation = 0.1
# Thus, we have L = 17678 and U = 19538
# populations: [18267, 18267, 18267, 18267, 18267, 18278, 18305, 18316, 18380, 18394, 18587, 18761, 18838, 18927, 19188, 19415, 19662, 19819, 19842, 19854, 19968, 19977, 20013, 20042, 20109, 20142, 20154, 20177, 20182, 20186]

# %%
len([18267, 18267, 18267, 18267, 18267, 18278, 18305, 18316, 18380, 18394, 18587, 18761, 18838, 18927, 19188, 19415, 19662, 19819, 19842, 19854, 19968, 19977, 20013, 20042, 20109, 20142, 20154, 20177, 20182, 20186])
# Out:
# 30

# %%
import networkx as nx

for (state, district_type) in [('WY','SS')]:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for district in plan:
        if not nx.is_connected( G.subgraph(district) ):
            print([len(comp) for comp in nx.connected_components(G.subgraph(district))])
    print("populations:",sorted([sum( G.nodes[i]['TOTPOP'] for i in district ) for district in plan ]) )
# Out:
# ****************************************
# Starting WY SS
# ****************************************
#
# Starting WY with k = 31 and deviation = 0.1
# Thus, we have L = 17678 and U = 19538
# populations: [17678, 17697, 17699, 17781, 17803, 17804, 17910, 18027, 18208, 18305, 18380, 18403, 18467, 18540, 18567, 18622, 18704, 18761, 18802, 18834, 18847, 18901, 18934, 19100, 19313, 19315, 19347, 19498, 19528, 19538, 19538]

# %%
failed_instances.remove(('WY','SS'))
len(failed_instances)
# Out:
# 18

# %%
for (state, district_type) in failed_instances:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for p in range(len(plan)):
        district = plan[p]
        if not nx.is_connected( G.subgraph(district) ):
            print("# =", p,"component sizes:",[len(comp) for comp in nx.connected_components(G.subgraph(district))],"and pops:",[sum(G.nodes[i]['TOTPOP'] for i in comp) for comp in nx.connected_components(G.subgraph(district))])
# Out:
# ****************************************
# Starting CA CD
# ****************************************
#
# Starting CA with k = 52 and deviation = 0.01
# Thus, we have L = 756549 and U = 764152
# ****************************************
# Starting CA SS
# ****************************************
#
# Starting CA with k = 40 and deviation = 0.1
# Thus, we have L = 939033 and U = 1037878
# # = 3 component sizes: [11315, 1] and pops: [1037511, 0]
# ****************************************
# Starting CA SH
# ****************************************
#
# Starting CA with k = 80 and deviation = 0.1
# Thus, we have L = 469517 and U = 518939
# # = 10 component sizes: [10722, 7] and pops: [470510, 0]
# # = 11 component sizes: [5678, 4] and pops: [471346, 0]
# # = 23 component sizes: [4131, 1] and pops: [483065, 0]
# # = 59 component sizes: [5277, 1] and pops: [518160, 0]
# ****************************************
# Starting DE SS
# ****************************************
#
# Starting DE with k = 21 and deviation = 0.1
# Thus, we have L = 44784 and U = 49497
# # = 15 component sizes: [612, 1] and pops: [48838, 0]
# ****************************************
# Starting DE SH
# ****************************************
#
# Starting DE with k = 41 and deviation = 0.1
# Thus, we have L = 22938 and U = 25352
# # = 0 component sizes: [455, 1] and pops: [24247, 0]
# # = 6 component sizes: [449, 1] and pops: [25281, 0]
# ****************************************
# Starting IL SH
# ****************************************
#
# Starting IL with k = 118 and deviation = 0.1
# Thus, we have L = 103152 and U = 114009
# # = 4 component sizes: [4391, 1] and pops: [104250, 0]
# ****************************************
# Starting MA SS
# ****************************************
#
# Starting MA with k = 40 and deviation = 0.1
# Thus, we have L = 166961 and U = 184535
# # = 15 component sizes: [2606, 3] and pops: [178660, 0]
# ****************************************
# Starting MA SH
# ****************************************
#
# Starting MA with k = 160 and deviation = 0.1
# Thus, we have L = 41741 and U = 46133
# # = 43 component sizes: [716, 3, 2] and pops: [45600, 0, 0]
# ****************************************
# Starting ME SS
# ****************************************
#
# Starting ME with k = 35 and deviation = 0.1
# Thus, we have L = 36979 and U = 40870
# # = 11 component sizes: [1596, 3] and pops: [40654, 2]
# ****************************************
# Starting MS SS
# ****************************************
#
# Starting MS with k = 52 and deviation = 0.1
# Thus, we have L = 54101 and U = 59795
# # = 11 component sizes: [1306, 11, 14] and pops: [59411, 0, 0]
# # = 13 component sizes: [1950, 9, 24] and pops: [58038, 0, 0]
# ****************************************
# Starting MS SH
# ****************************************
#
# Starting MS with k = 122 and deviation = 0.1
# Thus, we have L = 23060 and U = 25486
# # = 23 component sizes: [938, 24, 9] and pops: [23768, 0, 0]
# ****************************************
# Starting NY SH
# ****************************************
#
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# # = 104 component sizes: [5130, 2, 3, 2, 7, 2, 2, 2] and pops: [128857, 0, 0, 0, 2, 1, 0, 0]
# ****************************************
# Starting OH SH
# ****************************************
#
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# # = 13 component sizes: [2711, 55] and pops: [115935, 935]
# ****************************************
# Starting RI SS
# ****************************************
#
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# # = 34 component sizes: [342, 58, 1, 223] and pops: [20549, 231, 0, 8289]
# # = 36 component sizes: [437, 390] and pops: [17630, 12166]
# # = 37 component sizes: [826, 1] and pops: [30175, 0]
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# # = 7 component sizes: [2395, 6, 6] and pops: [226556, 0, 0]
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# # = 51 component sizes: [1140, 6, 6] and pops: [84453, 0, 0]
# # = 74 component sizes: [699, 5] and pops: [89690, 643]
# # = 88 component sizes: [798, 5] and pops: [90007, 536]
# ****************************************
# Starting WA SS
# ****************************************
#
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113
# ****************************************
# Starting WA SH
# ****************************************
#
# Starting WA with k = 49 and deviation = 0.1
# Thus, we have L = 149389 and U = 165113

# %%
failed_instances.remove( ('CA','CD') )
failed_instances.remove( ('WA','SS') )
failed_instances.remove( ('WA','SH') )
print(failed_instances)
# Out:
# [('CA', 'SS'), ('CA', 'SH'), ('DE', 'SS'), ('DE', 'SH'), ('IL', 'SH'), ('MA', 'SS'), ('MA', 'SH'), ('ME', 'SS'), ('MS', 'SS'), ('MS', 'SH'), ('NY', 'SH'), ('OH', 'SH'), ('RI', 'SS'), ('VA', 'SS'), ('VA', 'SH')]

# %%
for (state, district_type) in failed_instances:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for p in range(len(plan)):
        district = plan[p]
        if not nx.is_connected( G.subgraph(district) ):
            print("# =", p,"component sizes:",[len(comp) for comp in nx.connected_components(G.subgraph(district))],"and pops:",[sum(G.nodes[i]['TOTPOP'] for i in comp) for comp in nx.connected_components(G.subgraph(district))])
# Out:
# ****************************************
# Starting CA SS
# ****************************************
#
# Starting CA with k = 40 and deviation = 0.1
# Thus, we have L = 939033 and U = 1037878
# # = 3 component sizes: [11315, 1] and pops: [1037511, 0]
# ****************************************
# Starting CA SH
# ****************************************
#
# Starting CA with k = 80 and deviation = 0.1
# Thus, we have L = 469517 and U = 518939
# ****************************************
# Starting DE SS
# ****************************************
#
# Starting DE with k = 21 and deviation = 0.1
# Thus, we have L = 44784 and U = 49497
# ****************************************
# Starting DE SH
# ****************************************
#
# Starting DE with k = 41 and deviation = 0.1
# Thus, we have L = 22938 and U = 25352
# ****************************************
# Starting IL SH
# ****************************************
#
# Starting IL with k = 118 and deviation = 0.1
# Thus, we have L = 103152 and U = 114009
# # = 4 component sizes: [4391, 1] and pops: [104250, 0]
# ****************************************
# Starting MA SS
# ****************************************
#
# Starting MA with k = 40 and deviation = 0.1
# Thus, we have L = 166961 and U = 184535
# # = 15 component sizes: [2606, 3] and pops: [178660, 0]
# ****************************************
# Starting MA SH
# ****************************************
#
# Starting MA with k = 160 and deviation = 0.1
# Thus, we have L = 41741 and U = 46133
# # = 43 component sizes: [716, 2] and pops: [45600, 0]
# ****************************************
# Starting ME SS
# ****************************************
#
# Starting ME with k = 35 and deviation = 0.1
# Thus, we have L = 36979 and U = 40870
# # = 11 component sizes: [1596, 3] and pops: [40654, 2]
# ****************************************
# Starting MS SS
# ****************************************
#
# Starting MS with k = 52 and deviation = 0.1
# Thus, we have L = 54101 and U = 59795
# ****************************************
# Starting MS SH
# ****************************************
#
# Starting MS with k = 122 and deviation = 0.1
# Thus, we have L = 23060 and U = 25486
# ****************************************
# Starting NY SH
# ****************************************
#
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# # = 104 component sizes: [5130, 2, 3, 2, 7, 2, 2, 2] and pops: [128857, 0, 0, 0, 2, 1, 0, 0]
# ****************************************
# Starting OH SH
# ****************************************
#
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# # = 13 component sizes: [2711, 55] and pops: [115935, 935]
# ****************************************
# Starting RI SS
# ****************************************
#
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# # = 34 component sizes: [342, 58, 1, 223] and pops: [20549, 231, 0, 8289]
# # = 36 component sizes: [437, 390] and pops: [17630, 12166]
# # = 37 component sizes: [826, 1] and pops: [30175, 0]
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# # = 7 component sizes: [2395, 6, 6] and pops: [226556, 0, 0]
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# # = 51 component sizes: [1140, 6, 6] and pops: [84453, 0, 0]
# # = 74 component sizes: [699, 5] and pops: [89690, 643]
# # = 88 component sizes: [798, 5] and pops: [90007, 536]

# %%
failed_instances.remove( ('CA','SH') )
failed_instances.remove( ('DE','SS') )
failed_instances.remove( ('DE','SH') )

failed_instances.remove( ('MS','SS') )
failed_instances.remove( ('MS','SH') )

print(failed_instances)
# Out:
# [('CA', 'SS'), ('IL', 'SH'), ('MA', 'SS'), ('MA', 'SH'), ('ME', 'SS'), ('NY', 'SH'), ('OH', 'SH'), ('RI', 'SS'), ('VA', 'SS'), ('VA', 'SH')]

# %%
for (state, district_type) in failed_instances:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for p in range(len(plan)):
        district = plan[p]
        if not nx.is_connected( G.subgraph(district) ):
            print("# =", p,"component sizes:",[len(comp) for comp in nx.connected_components(G.subgraph(district))],"and pops:",[sum(G.nodes[i]['TOTPOP'] for i in comp) for comp in nx.connected_components(G.subgraph(district))])
# Out:
# ****************************************
# Starting CA SS
# ****************************************
#
# Starting CA with k = 40 and deviation = 0.1
# Thus, we have L = 939033 and U = 1037878
# ****************************************
# Starting IL SH
# ****************************************
#
# Starting IL with k = 118 and deviation = 0.1
# Thus, we have L = 103152 and U = 114009
# ****************************************
# Starting MA SS
# ****************************************
#
# Starting MA with k = 40 and deviation = 0.1
# Thus, we have L = 166961 and U = 184535
# # = 15 component sizes: [2606, 1] and pops: [178660, 0]
# ****************************************
# Starting MA SH
# ****************************************
#
# Starting MA with k = 160 and deviation = 0.1
# Thus, we have L = 41741 and U = 46133
# ****************************************
# Starting ME SS
# ****************************************
#
# Starting ME with k = 35 and deviation = 0.1
# Thus, we have L = 36979 and U = 40870
# # = 11 component sizes: [1596, 3] and pops: [40654, 2]
# ****************************************
# Starting NY SH
# ****************************************
#
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# # = 104 component sizes: [5130, 2, 3, 2, 7, 2, 2, 2] and pops: [128857, 0, 0, 0, 2, 1, 0, 0]
# ****************************************
# Starting OH SH
# ****************************************
#
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# # = 13 component sizes: [2711, 55] and pops: [115935, 935]
# ****************************************
# Starting RI SS
# ****************************************
#
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# # = 34 component sizes: [342, 58, 1, 223] and pops: [20549, 231, 0, 8289]
# # = 36 component sizes: [437, 390] and pops: [17630, 12166]
# # = 37 component sizes: [826, 1] and pops: [30175, 0]
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# # = 7 component sizes: [2395, 6, 6] and pops: [226556, 0, 0]
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# # = 51 component sizes: [1140, 6, 6] and pops: [84453, 0, 0]
# # = 74 component sizes: [699, 5] and pops: [89690, 643]
# # = 88 component sizes: [798, 5] and pops: [90007, 536]

# %%
failed_instances.remove( ('CA','SS') )

failed_instances.remove( ('IL','SH') )

failed_instances.remove( ('MA','SH') )

print(failed_instances)
# Out:
# [('MA', 'SS'), ('ME', 'SS'), ('NY', 'SH'), ('OH', 'SH'), ('RI', 'SS'), ('VA', 'SS'), ('VA', 'SH')]

# %%
for (state, district_type) in failed_instances:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for p in range(len(plan)):
        district = plan[p]
        if not nx.is_connected( G.subgraph(district) ):
            print("# =", p,"component sizes:",[len(comp) for comp in nx.connected_components(G.subgraph(district))],"and pops:",[sum(G.nodes[i]['TOTPOP'] for i in comp) for comp in nx.connected_components(G.subgraph(district))])
# Out:
# ****************************************
# Starting MA SS
# ****************************************
#
# Starting MA with k = 40 and deviation = 0.1
# Thus, we have L = 166961 and U = 184535
# ****************************************
# Starting ME SS
# ****************************************
#
# Starting ME with k = 35 and deviation = 0.1
# Thus, we have L = 36979 and U = 40870
# ****************************************
# Starting NY SH
# ****************************************
#
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# # = 104 component sizes: [5130, 2, 3, 2, 7, 2, 2, 2] and pops: [128857, 0, 0, 0, 2, 1, 0, 0]
# ****************************************
# Starting OH SH
# ****************************************
#
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# # = 13 component sizes: [2711, 55] and pops: [115935, 935]
# ****************************************
# Starting RI SS
# ****************************************
#
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# # = 34 component sizes: [342, 58, 1, 223] and pops: [20549, 231, 0, 8289]
# # = 36 component sizes: [437, 390] and pops: [17630, 12166]
# # = 37 component sizes: [826, 1] and pops: [30175, 0]
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# # = 7 component sizes: [2395, 6, 6] and pops: [226556, 0, 0]
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# # = 51 component sizes: [1140, 6, 6] and pops: [84453, 0, 0]
# # = 74 component sizes: [699, 5] and pops: [89690, 643]
# # = 88 component sizes: [798, 5] and pops: [90007, 536]

# %%
failed_instances.remove( ('MA','SS') )

failed_instances.remove( ('ME','SS') )

print(failed_instances)
# Out:
# [('NY', 'SH'), ('OH', 'SH'), ('RI', 'SS'), ('VA', 'SS'), ('VA', 'SH')]

# %%
for (state, district_type) in failed_instances:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for p in range(len(plan)):
        district = plan[p]
        if not nx.is_connected( G.subgraph(district) ):
            print("# =", p,"component sizes:",[len(comp) for comp in nx.connected_components(G.subgraph(district))],"and pops:",[sum(G.nodes[i]['TOTPOP'] for i in comp) for comp in nx.connected_components(G.subgraph(district))])
# Out:
# ****************************************
# Starting NY SH
# ****************************************
#
# Starting NY with k = 150 and deviation = 0.1
# Thus, we have L = 127942 and U = 141408
# ****************************************
# Starting OH SH
# ****************************************
#
# Starting OH with k = 99 and deviation = 0.1
# Thus, we have L = 113228 and U = 125145
# ****************************************
# Starting RI SS
# ****************************************
#
# Starting RI with k = 38 and deviation = 0.1
# Thus, we have L = 27435 and U = 30322
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# # = 7 component sizes: [2395, 6, 6] and pops: [226556, 0, 0]
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
# # = 51 component sizes: [1140, 6, 6] and pops: [84453, 0, 0]
# # = 74 component sizes: [699, 5] and pops: [89690, 643]
# # = 88 component sizes: [798, 5] and pops: [90007, 536]

# %%
failed_instances.remove( ('NY','SH') )
failed_instances.remove( ('OH','SH') )
failed_instances.remove( ('RI','SS') )

print(failed_instances)
# Out:
# [('VA', 'SS'), ('VA', 'SH')]

# %%
for (state, district_type) in failed_instances:
    
    print(f"{'*'*40}\nStarting {state} {district_type}\n{'*'*40}\n")   
    
    filename = state + '_' + level + '.json'
    G = read_graph_from_json( filepath + filename )
    update_attributes(G, state)

    (k, L, U) = get_k_L_U(G, state, district_type)
    if k <= 1:
        print("Skipping because k <= 1.")
        continue

    # get warm start plan
    filename = 'min_county_splits_' + state + '_' + district_type + '_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf'
    plan = import_from_baf(G, filepath2, filename)
    
    for p in range(len(plan)):
        district = plan[p]
        if not nx.is_connected( G.subgraph(district) ):
            print("# =", p,"component sizes:",[len(comp) for comp in nx.connected_components(G.subgraph(district))],"and pops:",[sum(G.nodes[i]['TOTPOP'] for i in comp) for comp in nx.connected_components(G.subgraph(district))])
# Out:
# ****************************************
# Starting VA SS
# ****************************************
#
# Starting VA with k = 40 and deviation = 0.1
# Thus, we have L = 204996 and U = 226574
# ****************************************
# Starting VA SH
# ****************************************
#
# Starting VA with k = 100 and deviation = 0.1
# Thus, we have L = 81999 and U = 90629
